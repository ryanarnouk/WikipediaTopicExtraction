# %% [markdown]
# # Simple Wikipedia Dataset Topic Extraction Using LDA
# # 1000 topics test
# Ryan Arnouk
#
# Latent Dirchilet Allocation: http://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf
#
# ## Latent Dirchilet Allocation (LDA) in Topic Modelling
# ### Explanation
# In natural language processing (NLP) latent Dirichlet allocation is a generative statistical model. This means the model can extract topics in an unlabeled dataset by frequency and distribution of words, to extract topics.
#
# LDA assumes all the words in a document are related and tries to figure out how each document could have been created. We need to just tell the model how many topics to construct to generate topic and word distributions over a corpus. Using this can allow us to identify similar documents within the corpus.
#
# Meaning, LDA Is useful for finding accurate mixtures of topics within a document.
#
# When using LDA you would choose a fixed number of topics (k) to discover from the dataset. In my case, I chose 200 to represent all the topics from the Simple Wikipedia Dataset.
#
# ### Assumptions
# - Documents with similar topics will use similar groups of words
# - Document definitions/modeling:
#   - Documents are probability distributions over latent topics
#   - Topics are probability distributions over words.
#
# Instead of focusing purely on frequency of words in a topic LDA focuses also on the distribution between words accross topics.
#
#
# ### Plate Notation
# A simple way to visually represent all the dependencies in the models parameters:
#
# ![Plate Notation](https://upload.wikimedia.org/wikipedia/commons/d/d3/Latent_Dirichlet_allocation.svg)
#
# By Bkkbrad - Own work, CC BY-SA 4.0, https://commons.wikimedia.org/w/index.php?curid=3610403
#
#
# M represents total number of documents within corpus
#
# N denotes number of words in a document
#
# Outside parameters:
# Dirchilet priors
# - α = the parameter of the Dirichlet prior on the per-document topic distributions
#     - High alpha denotes higher likelihood that each document is going to contain a mixture of the documents.
#     - Low alphas suggest that each document will only contain 1 or 2 topics
# - β = is the parameter of the Dirichlet prior on the per-topic word distribution
#     - High beta means each topic will contain a mixture of most of the words
#     - Low beta means each topic will only contain a mixture of a few words.
# - Theta: Topic distribution for the document
# - z notates each topic, making each document a mixture of these topics.
# - w stands for word
#
# ### How LDA Works
# **LDA Works Backwards**
#
# LDA runs in reverse, by starting with a corpus of documents and generating topics. In order to understand how LDA assumes the documents topics it is important to understand the generative process:
#
# LDA assumes documents are created in the same way:
# 1. Determine number of words in document
# 2. Choose a topic mixture for the document over a fixed set of topics (k)
#   a. Topic A: 20%
#   b. Topic B: 20%
#   c. Topic C: 60%
# 3. Generate topics in a document by:
#   a. First pick a topic a document in the topic distribution above.
#   b. Pick a word based on the topic distribution.
#
# Since we have a corpus of documents, we want LDA to learn the topic representation of K topics in each document and the word distribution of each topic.
#
# LDA **backtracks** from the document level to identify topics that have likely generated the corpus.
#
# Steps:
# - Randomly assign each word in each document to one of the K topics.
# - For each document d:
#   - Assume all the topic assignments except the current one are correct
#   - Calculate two proportions:
#     - Proportion of words in document d that are currently assigned to topic t
#     - Proportion of assignments to topic t over all documents that come from this word.
#
#   - Multiply the two proportions and assign w a new topic based on that probability.
# - Eventually a state would be reached where assignments make sense.
#
# ### LDA Pros vs Cons
#
# Pros:
# - Has been shown to produce good results over main domains
# - Effective, easy to understand tool.
#
# Cons:
# - Must know the number of topics K in advance (something that I struggled with in this project creating my own dataset) I would be forced to estimate a good number of topics for my needs.
# - Topic distribution cannot capture correlations among topics which makes it hard for me to group topics together as one. For example, linked lists and arrays are hard for me to group as simple computer science.
# - In my experience, it is a very tedious process discovering the optimal number of topics. There is not a very good explanation on the best way to determine the number of topics.
#
#
# ### Topic Modelling vs Topic Classification
# **Or LDA vs Neural Network**
#
# Difference between **identify one topic vs classify one topic**
#
# Originally, when working on this project I was under the impression I would use text classification and a neural network. However, I soon realized that this would be ineffective, based on the fact that despite having a define set of topic I would want to have returned I would not have any idea of the input text. Since I would have no idea what text or what subject the text inputted into the model would be, it would make more sense for me to try and extract the topic from any text instead of trying to classify an endless text from an endless amount of topics. If I was developing my model to be more niche in one subject, a neural network would definitely help improve my accuracy.
#
# Sources:
#
# https://www.youtube.com/watch?v=DWJYZq_fQ2A
#
# https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation
#
# https://www.quora.com/Latent-Dirichlet-Allocation-LDA-What-is-the-best-way-to-determine-k-number-of-topics-in-topic-modeling
#
# https://datascience.stackexchange.com/questions/962/what-is-difference-between-text-classification-and-topic-models

# %% [markdown]
# ## Import Dataset
# In my case, I am importing a Simple Wikipedia Dataset I already preprocessed from the XML file dump Wikipedia has publicly available. Parsing code available in *parse.py*

# %%
f = open('articles/articles.txt', 'r')
text = f.read()

# %% [markdown]
# ## Preprocessing
# The steps we need to do to preprocess our data is as follows:
#
# - Tokenization:
#   - Words with less than 3 characters must be removed. (Helps clear random words that may provide noise in the classifier)
# - All stop words are removed: Stop words are commonly used words like the, a, an, in that the classifier needs to be programmed to ignore to help keep noise levels in the classifier minimal.
# - Capitalization: Lowercase all the data
# - Stemming: Remove suffixes from words.
# - Lemmatization: Words in third person are changed to first person and verbs in past and future tenses are changed to present.
# - Vectorization: Convert words to vectors. Machine Learning can only read numbers so we must translate it to numbers.
#   - Types of vectorization includes:
#     - Bag of words (the technology used in this project)
#     - TFIDF
#     - Word2Vec
#     - GloVe

# %%
# import libraries 
import gensim
import nltk 
import numpy as np 

from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS 
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import * 

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# split each doc by a blank line
docs_all = text.split('\n\n')
print(docs_all[:5])
# Out:
# ['\n April is the fourth month of the year and comes between March and May It is one of four months to have day s April always starts on the same day of week as July and additionally January in leap years April always ends on the same day of the week as December April s flower s are the Sweet Pea and Asteraceae Daisy Its birthstone is the diamond The meaning of the diamond is innocence ', ' August is the eighth month of the year in the Gregorian calendar coming between July and September It has day s the same number of days as the previous month July and is named after Roman Emperor Augustus Caesar August doesn t start on the same day of the week as another month in Common year common years but starts on the same day of the week as February in Leap year leap years August always ends on the same day of the week as November ', ' Art is a creative activity by people The artist hopes that it affects the emotions of people who experience it Artists express themselves by their art Some people find art relaxing Many people disagree on how to define art Some say people are driven to make art due to their inner creativity Art includes drawing painting sculpting photography Performing arts performance art dance music poetry prose and theatre ', ' A is the first letter of the English language English alphabet The small letter a is used as a lower case vowel However the English long a omega the last letter of the Greek alphabet means the beginning and the end In musical notation the letter A is the symbol of a note in the scale below B and above G In binary numbers the letter A is A is the letter that was used to represent a team in an old TV show The A Team ', ' Administrators also called admins or sysops are users who can use special Special ListGroupRights Admin tools that help keep Wikipedia running smoothly They can use these tools because they are trusted by the community but this does not make them better or more important than anybody else The opinion of an administrator for example should not be counted as more important than the opinion of a person who chooses to change Wikipedia with an IP address just because they have administrator rights There are currently administrators ']

# %%
# Use all docs for training 
# docs_train = docs_all[:60000]
# no need for training data at all since we are using the model against unseen data
docs_train = docs_all

# %%
# preprocessing 
stemmer = SnowballStemmer("english")

def lemmatize_stemming(text):
  return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
  result=[]
  for token in gensim.utils.simple_preprocess(text) :
      if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
          result.append(lemmatize_stemming(token))
          
  return result

# %%
# assign processed_docs to preprocessed information
processed_docs = []

for doc in docs_train: 
  processed_docs.append(preprocess(doc))

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

#  checking dictionary created
count = 0
for k, v in dictionary.iteritems(): 
    print(k, v)
    count+=1
    if count > 10: 
        break

# gensim filter extremes
# filter words that appear less than no_below
# filter any words that do not appear in more than no_above
dictionary.filter_extremes(no_below=3, no_above=0.40)
# Out:
# 0 addit
# 1 april
# 2 asteracea
# 3 birthston
# 4 come
# 5 daisi
# 6 decemb
# 7 diamond
# 8 end
# 9 flower
# 10 fourth

# %%
import pickle

# gensim doc2bow
# convert document which is a list fo words into bag of words
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# running LDA on bad of words
lda_model = gensim.models.LdaMulticore(bow_corpus, 
                                      num_topics=1000,
                                      id2word=dictionary,
                                      passes=10, 
                                      iterations=100,
                                      workers=3)

# dump LDA model using pickle to use the model in the future without needing to rerun everything
ldafile = open('model2.pkl', 'wb')
pickle.dump(lda_model, ldafile)
ldafile.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
pickle_in = open('model2.pkl', 'rb')
loadlda = pickle.load(pickle_in)

# for each topic explore the words occuring in the topic and its relative weight 
for idx, topic in enumerate(loadlda.print_topics(num_topics=1000, num_words = 10)): # print 10 of the 350 topics
   print("Topic: {} \nWords: {}".format(idx, topic))
   print("\n")
# Out:
# Topic: 0
# Words: (0, '0.251*"peac" + 0.161*"anti" + 0.119*"fail" + 0.070*"metro" + 0.054*"circus" + 0.040*"elliott" + 0.034*"tension" + 0.029*"armor" + 0.025*"striker" + 0.022*"thomson"')
#
#
# Topic: 1
# Words: (1, '0.325*"compar" + 0.144*"constel" + 0.035*"thirteenth" + 0.032*"cunningham" + 0.031*"orion" + 0.027*"name" + 0.026*"barrett" + 0.024*"dane" + 0.018*"modern" + 0.018*"stella"')
#
#
# Topic: 2
# Words: (2, '0.265*"issu" + 0.259*"meet" + 0.105*"conflict" + 0.066*"debat" + 0.042*"karl" + 0.036*"millennium" + 0.035*"sacramento" + 0.021*"place" + 0.015*"begin" + 0.014*"peopl"')
#
#
# Topic: 3
# Words: (3, '0.153*"penguin" + 0.144*"syria" + 0.084*"indus" + 0.080*"balochistan" + 0.050*"low" + 0.049*"syrian" + 0.044*"appalachian" + 0.044*"wheeler" + 0.032*"sack" + 0.028*"thorp"')
#
#
# Topic: 4
# Words: (4, '0.151*"neutral" + 0.134*"shock" + 0.126*"jacob" + 0.089*"angola" + 0.064*"glori" + 0.048*"hymn" + 0.046*"usernam" + 0.039*"cameo" + 0.031*"astor" + 0.027*"brotherhood"')
#
#
# Topic: 5
# Words: (5, '0.244*"situat" + 0.117*"turkish" + 0.077*"nebula" + 0.070*"bit" + 0.067*"claus" + 0.061*"cyprus" + 0.058*"napl" + 0.049*"sardinia" + 0.038*"savoy" + 0.037*"negoti"')
#
#
# Topic: 6
# Words: (6, '0.242*"musician" + 0.136*"roll" + 0.116*"american" + 0.107*"jazz" + 0.076*"oliv" + 0.047*"charli" + 0.043*"know" + 0.025*"todd" + 0.024*"die" + 0.018*"best"')
#
#
# Topic: 7
# Words: (7, '0.461*"level" + 0.171*"girond" + 0.159*"aquitain" + 0.059*"harrison" + 0.046*"benjamin" + 0.025*"ahead" + 0.021*"harlan" + 0.015*"nouvell" + 0.012*"dull" + 0.009*"bordeaux"')
#
#
# Topic: 8
# Words: (8, '0.716*"river" + 0.098*"flow" + 0.036*"tributari" + 0.027*"substitut" + 0.024*"bath" + 0.012*"name" + 0.011*"long" + 0.010*"start" + 0.009*"form" + 0.007*"drain"')
#
#
# Topic: 9
# Words: (9, '0.377*"speci" + 0.095*"live" + 0.052*"frog" + 0.036*"leg" + 0.034*"egg" + 0.033*"common" + 0.031*"know" + 0.030*"small" + 0.026*"like" + 0.023*"long"')
#
#
# Topic: 10
# Words: (10, '0.273*"china" + 0.179*"chines" + 0.132*"read" + 0.115*"symbol" + 0.070*"peopl" + 0.042*"dragon" + 0.036*"benefit" + 0.029*"nation" + 0.028*"anthem" + 0.012*"write"')
#
#
# Topic: 11
# Words: (11, '0.244*"one" + 0.125*"literari" + 0.092*"han" + 0.064*"vladimir" + 0.058*"bori" + 0.041*"realist" + 0.031*"fist" + 0.023*"realism" + 0.023*"werner" + 0.020*"degrad"')
#
#
# Topic: 12
# Words: (12, '0.178*"indonesia" + 0.147*"mail" + 0.138*"googl" + 0.084*"unabl" + 0.068*"java" + 0.065*"competitor" + 0.029*"yahoo" + 0.020*"monsoon" + 0.019*"jakarta" + 0.015*"unus"')
#
#
# Topic: 13
# Words: (13, '0.110*"therapi" + 0.074*"plasma" + 0.072*"myer" + 0.071*"bleed" + 0.042*"analyt" + 0.041*"clot" + 0.034*"nude" + 0.031*"jung" + 0.027*"spaghetti" + 0.024*"form"')
#
#
# Topic: 14
# Words: (14, '0.635*"author" + 0.062*"leadership" + 0.061*"coffe" + 0.041*"regent" + 0.020*"squash" + 0.018*"brew" + 0.013*"modest" + 0.010*"titl" + 0.009*"shan" + 0.009*"ordovician"')
#
#
# Topic: 15
# Words: (15, '0.214*"explos" + 0.196*"russel" + 0.059*"explod" + 0.053*"blast" + 0.041*"burst" + 0.038*"adrian" + 0.026*"caus" + 0.024*"deton" + 0.022*"neutrino" + 0.018*"disarma"')
#
#
# Topic: 16
# Words: (16, '0.217*"franci" + 0.126*"graham" + 0.119*"catherin" + 0.094*"hopkin" + 0.050*"hedgehog" + 0.048*"kyle" + 0.044*"heath" + 0.034*"scrub" + 0.031*"medici" + 0.030*"bear"')
#
#
# Topic: 17
# Words: (17, '0.200*"suppli" + 0.199*"iowa" + 0.157*"growth" + 0.080*"convers" + 0.074*"derbi" + 0.066*"insur" + 0.038*"cellular" + 0.025*"moin" + 0.025*"unit" + 0.020*"slipknot"')
#
#
# Topic: 18
# Words: (18, '0.319*"manchest" + 0.131*"photograph" + 0.073*"export" + 0.073*"england" + 0.047*"indonesian" + 0.045*"textil" + 0.028*"literaci" + 0.028*"bali" + 0.020*"know" + 0.017*"salford"')
#
#
# Topic: 19
# Words: (19, '0.422*"east" + 0.180*"africa" + 0.174*"asia" + 0.058*"south" + 0.019*"countri" + 0.015*"sunni" + 0.013*"includ" + 0.013*"largest" + 0.011*"tunisia" + 0.010*"near"')
#
#
# Topic: 20
# Words: (20, '0.317*"hockey" + 0.132*"leagu" + 0.091*"play" + 0.052*"blackhawk" + 0.049*"game" + 0.047*"profession" + 0.036*"chicago" + 0.032*"american" + 0.029*"canadian" + 0.028*"season"')
#
#
# Topic: 21
# Words: (21, '0.216*"psycholog" + 0.163*"behavior" + 0.134*"physiolog" + 0.064*"psychologist" + 0.022*"chitral" + 0.021*"vishnu" + 0.021*"sage" + 0.021*"import" + 0.020*"avatar" + 0.019*"bodybuild"')
#
#
# Topic: 22
# Words: (22, '0.468*"texa" + 0.096*"phrase" + 0.082*"austin" + 0.073*"antonio" + 0.040*"state" + 0.036*"unit" + 0.030*"american" + 0.009*"year" + 0.008*"die" + 0.008*"begin"')
#
#
# Topic: 23
# Words: (23, '0.182*"syndic" + 0.133*"mandarin" + 0.064*"cantones" + 0.060*"macau" + 0.035*"sockpuppet" + 0.026*"angolan" + 0.025*"purdu" + 0.023*"freemason" + 0.023*"freemasonri" + 0.022*"howl"')
#
#
# Topic: 24
# Words: (24, '0.762*"studi" + 0.043*"linguist" + 0.032*"kenya" + 0.011*"hubbl" + 0.010*"discours" + 0.009*"know" + 0.008*"relat" + 0.007*"chang" + 0.007*"work" + 0.007*"involv"')
#
#
# Topic: 25
# Words: (25, '0.464*"road" + 0.295*"transport" + 0.047*"sight" + 0.037*"amazon" + 0.033*"venezuela" + 0.020*"run" + 0.019*"connect" + 0.011*"vehicl" + 0.007*"cushion" + 0.007*"toll"')
#
#
# Topic: 26
# Words: (26, '0.385*"case" + 0.142*"fast" + 0.069*"mention" + 0.055*"specifi" + 0.033*"usual" + 0.030*"recov" + 0.025*"need" + 0.024*"exampl" + 0.020*"pregnant" + 0.015*"reason"')
#
#
# Topic: 27
# Words: (27, '0.775*"station" + 0.065*"railway" + 0.052*"cargo" + 0.031*"main" + 0.022*"bus" + 0.008*"thoroughbr" + 0.005*"sire" + 0.005*"chairperson" + 0.005*"place" + 0.005*"name"')
#
#
# Topic: 28
# Words: (28, '0.324*"research" + 0.114*"applic" + 0.112*"lie" + 0.105*"resourc" + 0.091*"interact" + 0.037*"ecolog" + 0.032*"ecosystem" + 0.020*"wetland" + 0.018*"includ" + 0.013*"work"')
#
#
# Topic: 29
# Words: (29, '0.264*"januari" + 0.205*"octob" + 0.144*"year" + 0.058*"start" + 0.049*"calendar" + 0.035*"bear" + 0.031*"die" + 0.027*"common" + 0.023*"julian" + 0.022*"know"')
#
#
# Topic: 30
# Words: (30, '0.307*"festiv" + 0.210*"southeast" + 0.063*"year" + 0.032*"peopl" + 0.025*"famin" + 0.022*"place" + 0.020*"prosper" + 0.020*"dexter" + 0.018*"take" + 0.015*"footag"')
#
#
# Topic: 31
# Words: (31, '0.208*"distinguish" + 0.139*"tini" + 0.122*"particular" + 0.059*"conveni" + 0.059*"tire" + 0.054*"fraud" + 0.049*"specialis" + 0.044*"traction" + 0.043*"sterl" + 0.034*"unwant"')
#
#
# Topic: 32
# Words: (32, '0.330*"tabl" + 0.246*"wind" + 0.118*"tennesse" + 0.063*"gram" + 0.036*"furnitur" + 0.029*"pillar" + 0.016*"macquari" + 0.015*"igor" + 0.014*"grizzli" + 0.011*"din"')
#
#
# Topic: 33
# Words: (33, '0.773*"hill" + 0.056*"carriag" + 0.016*"bernardino" + 0.015*"liststyl" + 0.013*"titlestyl" + 0.010*"typewrit" + 0.010*"etymolog" + 0.008*"commonplac" + 0.007*"fledg" + 0.007*"advert"')
#
#
# Topic: 34
# Words: (34, '0.142*"imagin" + 0.068*"booker" + 0.066*"esperanto" + 0.057*"incomplet" + 0.055*"inscript" + 0.051*"elisabeth" + 0.047*"lazarus" + 0.045*"know" + 0.043*"etruscan" + 0.030*"luxor"')
#
#
# Topic: 35
# Words: (35, '0.147*"amount" + 0.137*"retriev" + 0.128*"pitch" + 0.091*"euro" + 0.081*"hardi" + 0.063*"augustus" + 0.042*"vale" + 0.040*"larg" + 0.040*"ensembl" + 0.029*"oxfordshir"')
#
#
# Topic: 36
# Words: (36, '0.240*"holi" + 0.110*"arctic" + 0.097*"sacr" + 0.086*"voyag" + 0.065*"shrine" + 0.042*"tibetan" + 0.033*"place" + 0.032*"hassan" + 0.023*"burmes" + 0.020*"scottsdal"')
#
#
# Topic: 37
# Words: (37, '0.207*"township" + 0.137*"bristol" + 0.048*"england" + 0.043*"warwickshir" + 0.038*"gloucestershir" + 0.031*"peggi" + 0.029*"avon" + 0.024*"superson" + 0.023*"severn" + 0.023*"stub"')
#
#
# Topic: 38
# Words: (38, '0.449*"magazin" + 0.101*"reader" + 0.078*"publish" + 0.048*"american" + 0.027*"cover" + 0.027*"state" + 0.026*"unit" + 0.023*"includ" + 0.018*"month" + 0.015*"appear"')
#
#
# Topic: 39
# Words: (39, '0.531*"rail" + 0.172*"steve" + 0.109*"phase" + 0.046*"innov" + 0.042*"acclaim" + 0.016*"earli" + 0.013*"high" + 0.011*"faint" + 0.008*"unit" + 0.006*"mpeg"')
#
#
# Topic: 40
# Words: (40, '0.443*"giant" + 0.219*"monster" + 0.033*"mythic" + 0.033*"sparrow" + 0.033*"sabha" + 0.025*"richi" + 0.025*"godzilla" + 0.023*"socialit" + 0.018*"goodwil" + 0.015*"larg"')
#
#
# Topic: 41
# Words: (41, '0.169*"plateau" + 0.130*"smash" + 0.077*"niec" + 0.070*"null" + 0.055*"prioriti" + 0.044*"edmond" + 0.037*"scarciti" + 0.035*"stipe" + 0.031*"mele" + 0.026*"snowboard"')
#
#
# Topic: 42
# Words: (42, '0.308*"carolina" + 0.282*"rank" + 0.064*"state" + 0.043*"unit" + 0.043*"wednesday" + 0.043*"monday" + 0.041*"tuesday" + 0.031*"thursday" + 0.027*"high" + 0.018*"savannah"')
#
#
# Topic: 43
# Words: (43, '0.178*"ancient" + 0.135*"surviv" + 0.118*"poet" + 0.104*"rome" + 0.066*"literatur" + 0.050*"poetri" + 0.049*"earliest" + 0.043*"write" + 0.037*"know" + 0.032*"treasur"')
#
#
# Topic: 44
# Words: (44, '0.318*"peak" + 0.260*"dakota" + 0.079*"maximum" + 0.060*"bullet" + 0.031*"lymphoma" + 0.030*"hulk" + 0.022*"northernmost" + 0.022*"state" + 0.017*"mecklenburg" + 0.016*"hodgkin"')
#
#
# Topic: 45
# Words: (45, '0.455*"garden" + 0.078*"indoor" + 0.067*"outdoor" + 0.053*"botan" + 0.050*"lemon" + 0.020*"place" + 0.015*"hartman" + 0.015*"median" + 0.013*"factual" + 0.013*"disadvantag"')
#
#
# Topic: 46
# Words: (46, '0.160*"buffalo" + 0.153*"lack" + 0.104*"reveal" + 0.092*"bill" + 0.066*"paradis" + 0.051*"wise" + 0.040*"wisdom" + 0.037*"eri" + 0.034*"fool" + 0.033*"sabr"')
#
#
# Topic: 47
# Words: (47, '0.209*"hope" + 0.106*"gill" + 0.073*"mushroom" + 0.059*"riley" + 0.057*"cohen" + 0.052*"herald" + 0.051*"theologian" + 0.038*"lassi" + 0.025*"mariann" + 0.024*"bear"')
#
#
# Topic: 48
# Words: (48, '0.438*"text" + 0.142*"daniel" + 0.079*"morn" + 0.077*"technic" + 0.073*"bold" + 0.043*"instanc" + 0.026*"wake" + 0.012*"oblig" + 0.011*"dysfunct" + 0.010*"bethesda"')
#
#
# Topic: 49
# Words: (49, '0.530*"england" + 0.209*"henri" + 0.036*"throne" + 0.034*"veteran" + 0.026*"widow" + 0.025*"die" + 0.025*"viii" + 0.016*"later" + 0.014*"tudor" + 0.012*"year"')
#
#
# Topic: 50
# Words: (50, '0.409*"engin" + 0.245*"structur" + 0.138*"construct" + 0.052*"work" + 0.028*"disciplin" + 0.017*"mainten" + 0.010*"includ" + 0.010*"differ" + 0.009*"sewag" + 0.008*"import"')
#
#
# Topic: 51
# Words: (51, '0.297*"golden" + 0.158*"globe" + 0.110*"cleveland" + 0.072*"oscar" + 0.059*"wyom" + 0.057*"screenplay" + 0.054*"bafta" + 0.046*"andrea" + 0.019*"cavali" + 0.016*"daytona"')
#
#
# Topic: 52
# Words: (52, '0.485*"institut" + 0.120*"simon" + 0.051*"shelter" + 0.047*"reconstruct" + 0.038*"bradford" + 0.037*"violet" + 0.027*"found" + 0.020*"tenur" + 0.017*"high" + 0.013*"cheng"')
#
#
# Topic: 53
# Words: (53, '0.605*"divis" + 0.207*"divid" + 0.051*"zero" + 0.035*"name" + 0.018*"cover" + 0.015*"origin" + 0.012*"chang" + 0.009*"part" + 0.007*"remaind" + 0.007*"thuringia"')
#
#
# Topic: 54
# Words: (54, '0.343*"true" + 0.201*"fact" + 0.131*"check" + 0.085*"statement" + 0.025*"actual" + 0.024*"thing" + 0.023*"think" + 0.018*"believ" + 0.016*"like" + 0.012*"show"')
#
#
# Topic: 55
# Words: (55, '0.332*"count" + 0.234*"shark" + 0.205*"matthew" + 0.021*"brabant" + 0.018*"boulogn" + 0.018*"silurian" + 0.016*"maud" + 0.013*"rigg" + 0.010*"largest" + 0.009*"mcmurray"')
#
#
# Topic: 56
# Words: (56, '0.303*"chairman" + 0.269*"buy" + 0.073*"holocaust" + 0.053*"luca" + 0.036*"chick" + 0.023*"prejudic" + 0.022*"halv" + 0.021*"bear" + 0.019*"imageri" + 0.018*"hatr"')
#
#
# Topic: 57
# Words: (57, '0.516*"edward" + 0.095*"biographi" + 0.034*"ladder" + 0.029*"live" + 0.026*"bear" + 0.022*"year" + 0.021*"die" + 0.017*"sinclair" + 0.015*"peyton" + 0.013*"later"')
#
#
# Topic: 58
# Words: (58, '0.217*"glass" + 0.103*"cut" + 0.055*"bottl" + 0.049*"evalu" + 0.047*"para" + 0.046*"stain" + 0.045*"transpar" + 0.032*"godfath" + 0.028*"jar" + 0.023*"aggreg"')
#
#
# Topic: 59
# Words: (59, '0.193*"page" + 0.175*"wikipedia" + 0.131*"talk" + 0.075*"articl" + 0.040*"help" + 0.034*"edit" + 0.028*"chang" + 0.016*"need" + 0.016*"like" + 0.013*"user"')
#
#
# Topic: 60
# Words: (60, '0.384*"inform" + 0.159*"websit" + 0.072*"hide" + 0.051*"key" + 0.017*"includ" + 0.013*"buddha" + 0.012*"peopl" + 0.012*"allow" + 0.011*"need" + 0.011*"plaintext"')
#
#
# Topic: 61
# Words: (61, '0.186*"owen" + 0.184*"biograph" + 0.034*"coldplay" + 0.034*"kean" + 0.033*"leningrad" + 0.029*"dmitri" + 0.026*"cockpit" + 0.025*"tarantula" + 0.022*"denzel" + 0.021*"novemb"')
#
#
# Topic: 62
# Words: (62, '0.625*"decemb" + 0.067*"novemb" + 0.047*"tenth" + 0.031*"beam" + 0.027*"septemb" + 0.023*"mdash" + 0.021*"twelfth" + 0.021*"microscop" + 0.011*"outlin" + 0.010*"year"')
#
#
# Topic: 63
# Words: (63, '0.543*"movement" + 0.163*"boy" + 0.039*"start" + 0.023*"base" + 0.014*"stub" + 0.014*"nucleotid" + 0.012*"earli" + 0.010*"bag" + 0.010*"sicilian" + 0.009*"want"')
#
#
# Topic: 64
# Words: (64, '0.284*"minor" + 0.184*"citizen" + 0.132*"denmark" + 0.074*"danish" + 0.053*"neil" + 0.052*"citizenship" + 0.042*"countri" + 0.030*"dual" + 0.025*"bear" + 0.017*"dare"')
#
#
# Topic: 65
# Words: (65, '0.338*"empir" + 0.274*"roman" + 0.025*"ottoman" + 0.024*"later" + 0.017*"year" + 0.017*"byzantin" + 0.012*"begin" + 0.012*"modern" + 0.010*"know" + 0.010*"come"')
#
#
# Topic: 66
# Words: (66, '0.460*"pictur" + 0.185*"motion" + 0.121*"screenwrit" + 0.040*"anni" + 0.037*"easter" + 0.031*"sidney" + 0.021*"stub" + 0.019*"vanuatu" + 0.015*"caravan" + 0.013*"write"')
#
#
# Topic: 67
# Words: (67, '0.410*"geobox" + 0.208*"interior" + 0.201*"wildlif" + 0.069*"unit" + 0.015*"sporophyt" + 0.012*"guantanamo" + 0.008*"keep" + 0.007*"horsetail" + 0.007*"origin" + 0.005*"state"')
#
#
# Topic: 68
# Words: (68, '0.113*"plat" + 0.079*"tidal" + 0.073*"vacuum" + 0.068*"syntax" + 0.063*"exclud" + 0.054*"microphon" + 0.044*"gujarat" + 0.040*"mosell" + 0.034*"capacitor" + 0.027*"mend"')
#
#
# Topic: 69
# Words: (69, '0.540*"templ" + 0.100*"promis" + 0.059*"abandon" + 0.038*"place" + 0.035*"uppsala" + 0.030*"famous" + 0.014*"import" + 0.012*"worship" + 0.012*"second" + 0.012*"world"')
#
#
# Topic: 70
# Words: (70, '0.339*"scientif" + 0.122*"tourism" + 0.081*"freshwat" + 0.072*"dublin" + 0.056*"superior" + 0.048*"cork" + 0.035*"chilean" + 0.035*"import" + 0.026*"mahogani" + 0.020*"micropolitan"')
#
#
# Topic: 71
# Words: (71, '0.311*"turkey" + 0.163*"berri" + 0.059*"ovari" + 0.055*"raspberri" + 0.044*"knockout" + 0.030*"lever" + 0.026*"martinez" + 0.026*"abolitionist" + 0.023*"cranberri" + 0.017*"brahmin"')
#
#
# Topic: 72
# Words: (72, '0.559*"cite" + 0.155*"galaxi" + 0.052*"maker" + 0.044*"junction" + 0.030*"year" + 0.025*"titl" + 0.024*"milki" + 0.013*"name" + 0.010*"andromeda" + 0.008*"larg"')
#
#
# Topic: 73
# Words: (73, '0.193*"remov" + 0.172*"add" + 0.115*"comment" + 0.075*"beat" + 0.069*"monitor" + 0.048*"slow" + 0.042*"accompani" + 0.037*"templat" + 0.031*"special" + 0.029*"long"')
#
#
# Topic: 74
# Words: (74, '0.187*"grass" + 0.169*"threaten" + 0.052*"anger" + 0.048*"lawn" + 0.043*"iucn" + 0.042*"rage" + 0.041*"herbac" + 0.035*"papyrus" + 0.029*"hermaphrodit" + 0.022*"chestnut"')
#
#
# Topic: 75
# Words: (75, '0.268*"kiss" + 0.098*"fortress" + 0.089*"intim" + 0.085*"papa" + 0.066*"reverend" + 0.056*"pearson" + 0.045*"escort" + 0.044*"surpass" + 0.036*"wwii" + 0.025*"semaphor"')
#
#
# Topic: 76
# Words: (76, '0.229*"larger" + 0.154*"pick" + 0.104*"smaller" + 0.080*"fee" + 0.062*"tend" + 0.057*"interchang" + 0.026*"usual" + 0.022*"cooki" + 0.022*"nest" + 0.021*"dirt"')
#
#
# Topic: 77
# Words: (77, '0.195*"earthquak" + 0.094*"magnitud" + 0.082*"healthi" + 0.080*"nephew" + 0.051*"haifa" + 0.046*"obstacl" + 0.037*"caus" + 0.035*"tsunami" + 0.032*"damag" + 0.031*"paleontologist"')
#
#
# Topic: 78
# Words: (78, '0.242*"constitut" + 0.223*"state" + 0.110*"unit" + 0.072*"amend" + 0.072*"confeder" + 0.024*"preced" + 0.020*"judici" + 0.013*"judiciari" + 0.011*"creat" + 0.011*"decis"')
#
#
# Topic: 79
# Words: (79, '0.269*"mine" + 0.141*"parker" + 0.051*"moodi" + 0.045*"sabbath" + 0.037*"recept" + 0.031*"rollin" + 0.030*"nevill" + 0.029*"saxophonist" + 0.025*"lizzi" + 0.024*"rotor"')
#
#
# Topic: 80
# Words: (80, '0.216*"indiana" + 0.148*"wayn" + 0.137*"rough" + 0.096*"gari" + 0.074*"indianapoli" + 0.061*"youtub" + 0.037*"marion" + 0.036*"state" + 0.034*"unit" + 0.023*"midwestern"')
#
#
# Topic: 81
# Words: (81, '0.292*"ball" + 0.290*"defin" + 0.058*"elli" + 0.047*"fenc" + 0.043*"incorrect" + 0.035*"batter" + 0.029*"raleigh" + 0.023*"base" + 0.022*"outfield" + 0.022*"foul"')
#
#
# Topic: 82
# Words: (82, '0.525*"republ" + 0.082*"crop" + 0.068*"czech" + 0.043*"felt" + 0.030*"weav" + 0.025*"fabric" + 0.023*"crusad" + 0.017*"wool" + 0.014*"countri" + 0.013*"peopl"')
#
#
# Topic: 83
# Words: (83, '0.278*"kennedi" + 0.130*"bread" + 0.072*"bake" + 0.050*"flour" + 0.049*"john" + 0.041*"lighter" + 0.038*"yeast" + 0.038*"sandwich" + 0.027*"make" + 0.026*"oven"')
#
#
# Topic: 84
# Words: (84, '0.206*"equal" + 0.202*"set" + 0.194*"poem" + 0.078*"epic" + 0.069*"journey" + 0.062*"financ" + 0.023*"write" + 0.016*"undefin" + 0.012*"poetri" + 0.012*"analogu"')
#
#
# Topic: 85
# Words: (85, '0.298*"pattern" + 0.089*"favorit" + 0.052*"richardson" + 0.052*"pooh" + 0.051*"geometr" + 0.046*"topolog" + 0.041*"winni" + 0.030*"exot" + 0.025*"base" + 0.020*"gideon"')
#
#
# Topic: 86
# Words: (86, '0.392*"meter" + 0.332*"tower" + 0.088*"brief" + 0.047*"hampton" + 0.029*"generic" + 0.029*"high" + 0.019*"migratori" + 0.014*"aragon" + 0.007*"tentat" + 0.005*"blackbird"')
#
#
# Topic: 87
# Words: (87, '0.170*"chair" + 0.117*"cattl" + 0.072*"penn" + 0.051*"herd" + 0.039*"upward" + 0.033*"retina" + 0.031*"ethan" + 0.031*"bullock" + 0.029*"cow" + 0.023*"eisner"')
#
#
# Topic: 88
# Words: (88, '0.149*"sicili" + 0.115*"ahm" + 0.094*"august" + 0.071*"nationwid" + 0.068*"milit" + 0.047*"septemb" + 0.039*"spokesman" + 0.037*"lankan" + 0.035*"courtyard" + 0.028*"tagalog"')
#
#
# Topic: 89
# Words: (89, '0.534*"govern" + 0.105*"countri" + 0.074*"state" + 0.060*"cabinet" + 0.031*"peopl" + 0.028*"unit" + 0.026*"offici" + 0.020*"parliamentari" + 0.018*"creat" + 0.017*"call"')
#
#
# Topic: 90
# Words: (90, '0.090*"hunt" + 0.080*"suggest" + 0.074*"chris" + 0.073*"predat" + 0.068*"seal" + 0.055*"prey" + 0.036*"live" + 0.034*"like" + 0.031*"carnivor" + 0.030*"falcon"')
#
#
# Topic: 91
# Words: (91, '0.312*"rest" + 0.167*"maria" + 0.077*"loud" + 0.061*"lesli" + 0.048*"whip" + 0.044*"crack" + 0.034*"shake" + 0.032*"hyde" + 0.029*"felix" + 0.029*"giusepp"')
#
#
# Topic: 92
# Words: (92, '0.161*"logo" + 0.117*"swamp" + 0.071*"scari" + 0.057*"anarchist" + 0.048*"ceas" + 0.043*"sonoma" + 0.042*"ell" + 0.037*"curtain" + 0.036*"anarchi" + 0.032*"anarch"')
#
#
# Topic: 93
# Words: (93, '0.163*"orient" + 0.124*"duck" + 0.092*"sheep" + 0.071*"somebodi" + 0.059*"beak" + 0.057*"brad" + 0.036*"goos" + 0.030*"relat" + 0.024*"heterosexu" + 0.023*"cosmopolitan"')
#
#
# Topic: 94
# Words: (94, '0.298*"bridg" + 0.294*"cross" + 0.147*"oklahoma" + 0.092*"equip" + 0.063*"civilian" + 0.035*"sultan" + 0.008*"state" + 0.005*"unit" + 0.005*"join" + 0.004*"stub"')
#
#
# Topic: 95
# Words: (95, '0.267*"analysi" + 0.201*"serial" + 0.178*"killer" + 0.045*"reson" + 0.032*"murder" + 0.025*"snyder" + 0.021*"know" + 0.019*"stub" + 0.018*"flap" + 0.016*"rod"')
#
#
# Topic: 96
# Words: (96, '0.184*"dive" + 0.126*"clock" + 0.081*"romeo" + 0.066*"cruz" + 0.061*"underwat" + 0.059*"tottenham" + 0.056*"juliet" + 0.045*"alarm" + 0.038*"explicit" + 0.037*"aluminum"')
#
#
# Topic: 97
# Words: (97, '0.126*"platinum" + 0.101*"certifi" + 0.059*"riaa" + 0.054*"state" + 0.048*"dylan" + 0.047*"sale" + 0.047*"mayflow" + 0.045*"gold" + 0.042*"unit" + 0.040*"leak"')
#
#
# Topic: 98
# Words: (98, '0.408*"success" + 0.292*"request" + 0.115*"wikipedia" + 0.067*"adminship" + 0.025*"advisor" + 0.014*"gore" + 0.012*"bureaucrat" + 0.009*"trader" + 0.008*"user" + 0.008*"bring"')
#
#
# Topic: 99
# Words: (99, '0.585*"report" + 0.039*"outbreak" + 0.038*"lauren" + 0.030*"melani" + 0.026*"conclud" + 0.023*"implic" + 0.022*"reunit" + 0.021*"catastroph" + 0.021*"weaker" + 0.021*"say"')
#
#
# Topic: 100
# Words: (100, '0.172*"degre" + 0.157*"graduat" + 0.132*"master" + 0.120*"earn" + 0.099*"cours" + 0.052*"bachelor" + 0.035*"high" + 0.029*"undergradu" + 0.027*"work" + 0.024*"marco"')
#
#
# Topic: 101
# Words: (101, '0.459*"franc" + 0.349*"region" + 0.189*"commune" + 0.000*"laon" + 0.000*"long" + 0.000*"peopl" + 0.000*"west" + 0.000*"combin" + 0.000*"live" + 0.000*"larger"')
#
#
# Topic: 102
# Words: (102, '0.243*"mechan" + 0.193*"foundat" + 0.164*"lincoln" + 0.058*"wikimedia" + 0.046*"joel" + 0.036*"dodger" + 0.035*"booth" + 0.026*"abraham" + 0.022*"echo" + 0.021*"work"')
#
#
# Topic: 103
# Words: (103, '0.181*"strike" + 0.167*"moor" + 0.084*"exercis" + 0.082*"cornwal" + 0.062*"lightn" + 0.046*"honey" + 0.045*"mill" + 0.032*"lorrain" + 0.026*"cornish" + 0.020*"nectar"')
#
#
# Topic: 104
# Words: (104, '0.216*"question" + 0.172*"romanc" + 0.150*"ask" + 0.078*"iranian" + 0.074*"correspond" + 0.066*"portugues" + 0.035*"luck" + 0.027*"extent" + 0.019*"fate" + 0.013*"origin"')
#
#
# Topic: 105
# Words: (105, '0.167*"sauc" + 0.136*"singh" + 0.084*"manila" + 0.081*"relev" + 0.052*"telugu" + 0.047*"worcestershir" + 0.042*"shri" + 0.040*"kannada" + 0.036*"laguna" + 0.028*"omit"')
#
#
# Topic: 106
# Words: (106, '0.599*"music" + 0.106*"compos" + 0.066*"write" + 0.025*"work" + 0.018*"know" + 0.015*"famous" + 0.015*"sing" + 0.014*"includ" + 0.011*"cole" + 0.009*"perform"')
#
#
# Topic: 107
# Words: (107, '0.214*"roger" + 0.169*"dedic" + 0.130*"neighborhood" + 0.128*"icon" + 0.097*"fred" + 0.072*"congression" + 0.042*"postcod" + 0.023*"peabodi" + 0.019*"norwood" + 0.013*"stub"')
#
#
# Topic: 108
# Words: (108, '0.398*"tournament" + 0.108*"bever" + 0.101*"prais" + 0.071*"satir" + 0.046*"static" + 0.039*"take" + 0.038*"place" + 0.020*"alfonso" + 0.019*"rey" + 0.018*"year"')
#
#
# Topic: 109
# Words: (109, '0.625*"park" + 0.133*"nation" + 0.038*"top" + 0.025*"anatomi" + 0.020*"permit" + 0.014*"name" + 0.010*"world" + 0.010*"place" + 0.010*"yellowston" + 0.009*"fokker"')
#
#
# Topic: 110
# Words: (110, '0.352*"environ" + 0.109*"wait" + 0.074*"bahrain" + 0.070*"khalifa" + 0.064*"rubber" + 0.062*"sheikh" + 0.036*"leipzig" + 0.035*"hamad" + 0.027*"qatar" + 0.016*"live"')
#
#
# Topic: 111
# Words: (111, '0.212*"pay" + 0.205*"editor" + 0.184*"tour" + 0.167*"tool" + 0.083*"crystal" + 0.062*"peopl" + 0.027*"inject" + 0.017*"work" + 0.009*"isom" + 0.009*"leav"')
#
#
# Topic: 112
# Words: (112, '0.178*"incid" + 0.170*"jonathan" + 0.138*"trilog" + 0.100*"clown" + 0.077*"drown" + 0.033*"casualti" + 0.019*"nofx" + 0.017*"djibouti" + 0.016*"lose" + 0.016*"happen"')
#
#
# Topic: 113
# Words: (113, '0.674*"list" + 0.202*"articl" + 0.045*"expand" + 0.019*"includ" + 0.011*"contain" + 0.010*"vital" + 0.007*"stub" + 0.007*"largest" + 0.004*"basic" + 0.003*"need"')
#
#
# Topic: 114
# Words: (114, '0.176*"monarch" + 0.119*"mediev" + 0.088*"renaiss" + 0.070*"middlesex" + 0.065*"rhyme" + 0.052*"duchi" + 0.030*"referendum" + 0.030*"pipelin" + 0.022*"heathrow" + 0.020*"call"')
#
#
# Topic: 115
# Words: (115, '0.295*"cemeteri" + 0.094*"wealth" + 0.088*"punch" + 0.085*"judi" + 0.064*"nation" + 0.047*"natali" + 0.029*"thrasher" + 0.027*"inquiri" + 0.022*"portman" + 0.021*"genealog"')
#
#
# Topic: 116
# Words: (116, '0.255*"lot" + 0.153*"eleph" + 0.061*"plug" + 0.057*"crush" + 0.039*"hummingbird" + 0.036*"registr" + 0.036*"ultraviolet" + 0.030*"peopl" + 0.029*"prosecut" + 0.028*"condemn"')
#
#
# Topic: 117
# Words: (117, '0.297*"stage" + 0.242*"better" + 0.217*"view" + 0.098*"know" + 0.045*"narrat" + 0.017*"bear" + 0.013*"perspect" + 0.009*"later" + 0.007*"preval" + 0.007*"american"')
#
#
# Topic: 118
# Words: (118, '0.175*"aliv" + 0.144*"ralph" + 0.089*"helena" + 0.076*"rainbow" + 0.061*"bolivia" + 0.047*"vomit" + 0.044*"reflex" + 0.038*"aegean" + 0.027*"ascens" + 0.026*"tristan"')
#
#
# Topic: 119
# Words: (119, '0.526*"languag" + 0.128*"speak" + 0.059*"peopl" + 0.027*"polish" + 0.025*"poland" + 0.018*"countri" + 0.018*"offici" + 0.016*"mean" + 0.014*"write" + 0.011*"call"')
#
#
# Topic: 120
# Words: (120, '0.162*"examin" + 0.154*"munich" + 0.123*"bavaria" + 0.085*"ludwig" + 0.082*"preston" + 0.070*"qualif" + 0.056*"assess" + 0.034*"deed" + 0.030*"adher" + 0.024*"carrion"')
#
#
# Topic: 121
# Words: (121, '0.786*"current" + 0.124*"merg" + 0.014*"otto" + 0.013*"coil" + 0.009*"thor" + 0.009*"stub" + 0.006*"short" + 0.006*"chang" + 0.004*"villanova" + 0.002*"consist"')
#
#
# Topic: 122
# Words: (122, '0.517*"victoria" + 0.282*"mount" + 0.034*"includ" + 0.025*"name" + 0.020*"cascad" + 0.017*"year" + 0.015*"near" + 0.013*"molar" + 0.012*"state" + 0.005*"incisor"')
#
#
# Topic: 123
# Words: (123, '0.258*"seventh" + 0.224*"miller" + 0.112*"denomin" + 0.078*"judgment" + 0.068*"evangel" + 0.019*"start" + 0.019*"adventist" + 0.019*"advent" + 0.016*"ecclesiast" + 0.014*"unit"')
#
#
# Topic: 124
# Words: (124, '0.325*"depart" + 0.159*"north" + 0.152*"picardi" + 0.150*"aisn" + 0.055*"franc" + 0.034*"somm" + 0.021*"relief" + 0.020*"peopl" + 0.019*"live" + 0.014*"basqu"')
#
#
# Topic: 125
# Words: (125, '0.527*"parti" + 0.142*"democrat" + 0.108*"republican" + 0.027*"nation" + 0.023*"state" + 0.022*"unit" + 0.015*"member" + 0.013*"polit" + 0.012*"lose" + 0.010*"form"')
#
#
# Topic: 126
# Words: (126, '0.321*"rugbi" + 0.089*"armour" + 0.074*"guin" + 0.072*"trunk" + 0.054*"aerial" + 0.042*"wallabi" + 0.038*"tackl" + 0.038*"shale" + 0.037*"world" + 0.036*"repli"')
#
#
# Topic: 127
# Words: (127, '0.343*"februari" + 0.208*"month" + 0.177*"day" + 0.070*"year" + 0.063*"extra" + 0.030*"ordinari" + 0.030*"even" + 0.023*"august" + 0.011*"take" + 0.008*"abduct"')
#
#
# Topic: 128
# Words: (128, '0.151*"advantag" + 0.087*"allow" + 0.074*"suitabl" + 0.067*"bless" + 0.061*"horizon" + 0.059*"circumst" + 0.054*"compat" + 0.034*"muscular" + 0.034*"temporarili" + 0.023*"aqua"')
#
#
# Topic: 129
# Words: (129, '0.333*"declar" + 0.087*"newli" + 0.080*"nation" + 0.080*"resolut" + 0.071*"unit" + 0.068*"palmer" + 0.064*"state" + 0.042*"intersect" + 0.025*"sanford" + 0.024*"subdivid"')
#
#
# Topic: 130
# Words: (130, '0.419*"review" + 0.196*"adult" + 0.140*"spin" + 0.063*"reproduct" + 0.032*"guardian" + 0.031*"matur" + 0.030*"peer" + 0.028*"reproduc" + 0.008*"bragg" + 0.007*"adulthood"')
#
#
# Topic: 131
# Words: (131, '0.097*"comparison" + 0.084*"kurt" + 0.067*"anal" + 0.061*"lunch" + 0.057*"vulcan" + 0.053*"burrough" + 0.043*"seward" + 0.039*"surreal" + 0.036*"hoax" + 0.029*"terr"')
#
#
# Topic: 132
# Words: (132, '0.258*"berlin" + 0.088*"thread" + 0.073*"affili" + 0.071*"spike" + 0.063*"nail" + 0.059*"spiral" + 0.052*"bolt" + 0.050*"groov" + 0.049*"screw" + 0.026*"polytechn"')
#
#
# Topic: 133
# Words: (133, '0.201*"frame" + 0.138*"sonic" + 0.116*"fraction" + 0.101*"chuck" + 0.067*"resolv" + 0.062*"boom" + 0.045*"gavin" + 0.034*"norma" + 0.019*"mouthpiec" + 0.016*"thermoset"')
#
#
# Topic: 134
# Words: (134, '0.190*"pittsburgh" + 0.184*"snow" + 0.111*"freez" + 0.078*"melt" + 0.061*"thunder" + 0.035*"perfum" + 0.029*"blizzard" + 0.021*"bernstein" + 0.020*"steeler" + 0.020*"ibrahim"')
#
#
# Topic: 135
# Words: (135, '0.242*"fellow" + 0.086*"disco" + 0.060*"samoa" + 0.050*"pale" + 0.049*"panic" + 0.042*"rita" + 0.036*"tomorrow" + 0.032*"isabella" + 0.024*"american" + 0.023*"bear"')
#
#
# Topic: 136
# Words: (136, '0.163*"factori" + 0.114*"thirti" + 0.111*"thank" + 0.102*"aim" + 0.100*"stretch" + 0.083*"excel" + 0.062*"salem" + 0.051*"seth" + 0.029*"macfarlan" + 0.024*"gemston"')
#
#
# Topic: 137
# Words: (137, '0.327*"babi" + 0.098*"analog" + 0.077*"pregnanc" + 0.075*"cardiac" + 0.050*"manuel" + 0.044*"synthes" + 0.043*"beverag" + 0.032*"pulp" + 0.032*"bear" + 0.024*"bangor"')
#
#
# Topic: 138
# Words: (138, '0.161*"jose" + 0.149*"costa" + 0.089*"rica" + 0.073*"lowland" + 0.062*"mann" + 0.045*"sufi" + 0.036*"sunda" + 0.036*"byrd" + 0.034*"marlborough" + 0.027*"briton"')
#
#
# Topic: 139
# Words: (139, '0.426*"celebr" + 0.137*"fluid" + 0.067*"dynam" + 0.048*"simul" + 0.047*"parad" + 0.036*"lesson" + 0.032*"scroll" + 0.025*"peopl" + 0.017*"countri" + 0.015*"like"')
#
#
# Topic: 140
# Words: (140, '0.205*"ring" + 0.174*"planet" + 0.140*"orbit" + 0.064*"asteroid" + 0.063*"belt" + 0.060*"saturn" + 0.031*"jupit" + 0.027*"name" + 0.027*"neptun" + 0.026*"know"')
#
#
# Topic: 141
# Words: (141, '0.225*"feel" + 0.171*"peopl" + 0.051*"like" + 0.048*"want" + 0.039*"currenc" + 0.037*"thing" + 0.027*"say" + 0.025*"think" + 0.023*"intermedi" + 0.020*"mean"')
#
#
# Topic: 142
# Words: (142, '0.280*"philosophi" + 0.250*"philosoph" + 0.108*"absolut" + 0.045*"nathan" + 0.033*"know" + 0.031*"shawn" + 0.025*"socrat" + 0.017*"maneuv" + 0.017*"hobbit" + 0.015*"boyz"')
#
#
# Topic: 143
# Words: (143, '0.212*"mediterranean" + 0.155*"mainland" + 0.146*"tasmania" + 0.125*"juan" + 0.047*"westwood" + 0.043*"australasia" + 0.032*"hobart" + 0.030*"warmer" + 0.030*"whistler" + 0.025*"tasmanian"')
#
#
# Topic: 144
# Words: (144, '0.621*"record" + 0.069*"american" + 0.052*"rapper" + 0.042*"produc" + 0.040*"marshal" + 0.034*"eighth" + 0.020*"studio" + 0.017*"novemb" + 0.013*"cent" + 0.012*"eminem"')
#
#
# Topic: 145
# Words: (145, '0.177*"extern" + 0.143*"recognit" + 0.095*"opportun" + 0.067*"versus" + 0.051*"seasid" + 0.043*"edison" + 0.033*"reagent" + 0.028*"moldova" + 0.021*"work" + 0.020*"unrecogn"')
#
#
# Topic: 146
# Words: (146, '0.242*"prevent" + 0.109*"diet" + 0.098*"employe" + 0.081*"childhood" + 0.046*"specialist" + 0.041*"sperm" + 0.036*"embryo" + 0.030*"adolesc" + 0.027*"fertilis" + 0.024*"salari"')
#
#
# Topic: 147
# Words: (147, '0.273*"church" + 0.194*"christian" + 0.115*"cathol" + 0.037*"roman" + 0.029*"christ" + 0.027*"priest" + 0.023*"orthodox" + 0.021*"welcom" + 0.012*"religi" + 0.010*"john"')
#
#
# Topic: 148
# Words: (148, '0.435*"canada" + 0.330*"canadian" + 0.072*"centr" + 0.066*"gordon" + 0.012*"robertson" + 0.010*"favourit" + 0.008*"novemb" + 0.007*"unit" + 0.006*"bear" + 0.006*"countri"')
#
#
# Topic: 149
# Words: (149, '0.180*"panther" + 0.145*"exit" + 0.131*"doom" + 0.067*"cougar" + 0.066*"roar" + 0.039*"kelvin" + 0.026*"puma" + 0.025*"almanac" + 0.025*"growl" + 0.019*"hiss"')
#
#
# Topic: 150
# Words: (150, '0.282*"nativ" + 0.239*"technolog" + 0.106*"american" + 0.084*"religi" + 0.065*"worth" + 0.039*"state" + 0.029*"unit" + 0.024*"mascot" + 0.020*"beaver" + 0.015*"nation"')
#
#
# Topic: 151
# Words: (151, '0.331*"corpor" + 0.221*"suburb" + 0.085*"deposit" + 0.041*"lancast" + 0.035*"treasuri" + 0.033*"yield" + 0.024*"farther" + 0.017*"grow" + 0.015*"outward" + 0.015*"comed"')
#
#
# Topic: 152
# Words: (152, '0.953*"north" + 0.012*"instant" + 0.010*"timor" + 0.003*"jazzi" + 0.002*"smaller" + 0.002*"live" + 0.002*"dili" + 0.001*"pterygota" + 0.001*"lawless" + 0.001*"simpli"')
#
#
# Topic: 153
# Words: (153, '0.346*"villag" + 0.279*"street" + 0.076*"manhattan" + 0.061*"wolf" + 0.031*"near" + 0.025*"small" + 0.025*"grid" + 0.020*"residenti" + 0.020*"main" + 0.020*"greenwich"')
#
#
# Topic: 154
# Words: (154, '0.290*"committe" + 0.147*"elector" + 0.108*"samuel" + 0.089*"disput" + 0.067*"pure" + 0.055*"stomach" + 0.035*"hay" + 0.035*"bare" + 0.034*"reactiv" + 0.025*"rutherford"')
#
#
# Topic: 155
# Words: (155, '0.399*"function" + 0.130*"oxford" + 0.106*"historian" + 0.076*"regard" + 0.070*"gang" + 0.047*"johann" + 0.029*"bach" + 0.027*"wilhelm" + 0.021*"sebastian" + 0.012*"fulfil"')
#
#
# Topic: 156
# Words: (156, '0.389*"columbia" + 0.184*"stick" + 0.097*"freestyl" + 0.041*"lacross" + 0.037*"ebert" + 0.033*"carnegi" + 0.031*"marlin" + 0.025*"blacklist" + 0.023*"angelo" + 0.022*"can"')
#
#
# Topic: 157
# Words: (157, '0.458*"term" + 0.103*"refer" + 0.052*"mean" + 0.043*"confus" + 0.034*"slight" + 0.031*"usag" + 0.028*"common" + 0.024*"usual" + 0.021*"describ" + 0.017*"similar"')
#
#
# Topic: 158
# Words: (158, '0.448*"cell" + 0.171*"wall" + 0.042*"membran" + 0.035*"rival" + 0.025*"insid" + 0.017*"form" + 0.015*"chembox" + 0.014*"call" + 0.013*"small" + 0.013*"outsid"')
#
#
# Topic: 159
# Words: (159, '0.331*"crash" + 0.139*"impact" + 0.105*"liberti" + 0.082*"tear" + 0.078*"merit" + 0.045*"traci" + 0.023*"peopl" + 0.021*"septemb" + 0.018*"die" + 0.015*"steadili"')
#
#
# Topic: 160
# Words: (160, '0.271*"treati" + 0.132*"hudson" + 0.095*"campbel" + 0.040*"birch" + 0.034*"versaill" + 0.029*"countri" + 0.027*"cannabi" + 0.026*"marijuana" + 0.026*"demograph" + 0.023*"sleepi"')
#
#
# Topic: 161
# Words: (161, '0.344*"enter" + 0.159*"stream" + 0.099*"loop" + 0.035*"waterfal" + 0.027*"empti" + 0.025*"provid" + 0.020*"near" + 0.019*"join" + 0.018*"watersh" + 0.014*"form"')
#
#
# Topic: 162
# Words: (162, '0.271*"vermont" + 0.098*"aberdeen" + 0.085*"state" + 0.085*"thermodynam" + 0.060*"kensington" + 0.056*"burlington" + 0.043*"milli" + 0.034*"iroquoi" + 0.025*"unit" + 0.022*"doric"')
#
#
# Topic: 163
# Words: (163, '0.186*"ridg" + 0.176*"hawaii" + 0.120*"sandi" + 0.077*"includeon" + 0.047*"hawaiian" + 0.045*"boni" + 0.033*"honolulu" + 0.029*"cuckoo" + 0.027*"polynesia" + 0.025*"scissor"')
#
#
# Topic: 164
# Words: (164, '0.275*"abil" + 0.254*"eye" + 0.076*"oral" + 0.059*"elast" + 0.056*"bosnia" + 0.044*"herzegovina" + 0.043*"audi" + 0.032*"facial" + 0.026*"puriti" + 0.025*"seneg"')
#
#
# Topic: 165
# Words: (165, '0.219*"skate" + 0.164*"carol" + 0.090*"benedict" + 0.071*"interv" + 0.049*"mummi" + 0.049*"straw" + 0.026*"mater" + 0.023*"chun" + 0.023*"choi" + 0.022*"tammi"')
#
#
# Topic: 166
# Words: (166, '0.250*"dalla" + 0.161*"molecular" + 0.146*"contrast" + 0.094*"arlington" + 0.086*"clade" + 0.040*"shanghai" + 0.022*"siemen" + 0.016*"anatom" + 0.016*"aichi" + 0.015*"biolog"')
#
#
# Topic: 167
# Words: (167, '0.187*"heat" + 0.151*"parish" + 0.137*"cold" + 0.136*"temperatur" + 0.056*"westminst" + 0.025*"high" + 0.021*"thermal" + 0.017*"chang" + 0.016*"precipit" + 0.013*"ceil"')
#
#
# Topic: 168
# Words: (168, '0.638*"depart" + 0.125*"franc" + 0.107*"commune" + 0.051*"loir" + 0.033*"sarth" + 0.024*"implement" + 0.004*"lagrang" + 0.003*"compulsori" + 0.002*"stade" + 0.001*"main"')
#
#
# Topic: 169
# Words: (169, '0.067*"hertfordshir" + 0.060*"barrymor" + 0.058*"weston" + 0.056*"jellyfish" + 0.055*"hepburn" + 0.053*"alban" + 0.047*"freight" + 0.040*"tentacl" + 0.034*"katharin" + 0.029*"cnidaria"')
#
#
# Topic: 170
# Words: (170, '0.246*"austria" + 0.207*"philippin" + 0.180*"fashion" + 0.103*"vienna" + 0.077*"refus" + 0.044*"oversea" + 0.022*"know" + 0.019*"countri" + 0.016*"falkland" + 0.015*"world"')
#
#
# Topic: 171
# Words: (171, '0.352*"super" + 0.214*"bowl" + 0.119*"kevin" + 0.052*"jet" + 0.038*"legaci" + 0.032*"trench" + 0.022*"flynn" + 0.021*"ditch" + 0.011*"american" + 0.011*"know"')
#
#
# Topic: 172
# Words: (172, '0.644*"point" + 0.069*"mous" + 0.041*"mickey" + 0.023*"ram" + 0.021*"loyal" + 0.016*"gentl" + 0.015*"clergi" + 0.014*"call" + 0.013*"pencil" + 0.013*"monetari"')
#
#
# Topic: 173
# Words: (173, '0.306*"hair" + 0.178*"incorpor" + 0.046*"daisi" + 0.040*"beard" + 0.039*"whilst" + 0.036*"chin" + 0.033*"addam" + 0.031*"sulfid" + 0.028*"viacom" + 0.027*"cobalt"')
#
#
# Topic: 174
# Words: (174, '0.857*"univers" + 0.032*"campus" + 0.023*"state" + 0.016*"bear" + 0.012*"lucern" + 0.006*"best" + 0.005*"higher" + 0.005*"name" + 0.005*"world" + 0.005*"start"')
#
#
# Topic: 175
# Words: (175, '0.364*"angel" + 0.168*"california" + 0.147*"american" + 0.104*"bear" + 0.055*"die" + 0.033*"orlando" + 0.020*"know" + 0.010*"neolith" + 0.009*"hispan" + 0.008*"live"')
#
#
# Topic: 176
# Words: (176, '0.240*"appoint" + 0.209*"arthur" + 0.105*"portug" + 0.097*"stuart" + 0.075*"economist" + 0.053*"wound" + 0.053*"jeremi" + 0.042*"john" + 0.019*"portugues" + 0.017*"thinker"')
#
#
# Topic: 177
# Words: (177, '0.481*"presid" + 0.177*"state" + 0.159*"unit" + 0.029*"inaugur" + 0.014*"second" + 0.013*"found" + 0.011*"nation" + 0.011*"take" + 0.010*"presidenti" + 0.010*"elect"')
#
#
# Topic: 178
# Words: (178, '0.294*"father" + 0.252*"brother" + 0.066*"younger" + 0.048*"bear" + 0.042*"die" + 0.039*"elder" + 0.035*"muhammad" + 0.024*"later" + 0.023*"luci" + 0.021*"imprison"')
#
#
# Topic: 179
# Words: (179, '0.621*"million" + 0.143*"worldwid" + 0.040*"dave" + 0.029*"soni" + 0.026*"blake" + 0.025*"tap" + 0.023*"powel" + 0.013*"slade" + 0.011*"rubi" + 0.007*"today"')
#
#
# Topic: 180
# Words: (180, '0.247*"hollywood" + 0.171*"mexican" + 0.161*"illustr" + 0.055*"squad" + 0.054*"weaver" + 0.027*"noodl" + 0.026*"miguel" + 0.024*"american" + 0.024*"adob" + 0.017*"guerrero"')
#
#
# Topic: 181
# Words: (181, '0.587*"mass" + 0.052*"salvador" + 0.033*"charm" + 0.029*"relat" + 0.029*"brigadi" + 0.028*"wyatt" + 0.022*"earp" + 0.018*"schwartz" + 0.016*"enthusiast" + 0.014*"slap"')
#
#
# Topic: 182
# Words: (182, '0.147*"colombia" + 0.129*"kitchen" + 0.111*"jurisdict" + 0.110*"curti" + 0.102*"juic" + 0.076*"chef" + 0.040*"tame" + 0.022*"aphid" + 0.021*"mouthpart" + 0.020*"pendulum"')
#
#
# Topic: 183
# Words: (183, '0.183*"usher" + 0.134*"cognit" + 0.076*"uganda" + 0.049*"cum" + 0.045*"rama" + 0.035*"sagittarius" + 0.032*"sexi" + 0.028*"think" + 0.026*"shill" + 0.026*"shutter"')
#
#
# Topic: 184
# Words: (184, '0.237*"volleybal" + 0.133*"botani" + 0.113*"emb" + 0.085*"clarinet" + 0.083*"botanist" + 0.038*"vegan" + 0.033*"especi" + 0.032*"ligatur" + 0.017*"palma" + 0.017*"canto"')
#
#
# Topic: 185
# Words: (185, '0.400*"bell" + 0.159*"southwestern" + 0.119*"readi" + 0.108*"bar" + 0.024*"keeper" + 0.020*"reel" + 0.016*"battersea" + 0.014*"sheppard" + 0.013*"navajo" + 0.012*"get"')
#
#
# Topic: 186
# Words: (186, '0.255*"destroy" + 0.194*"lose" + 0.164*"eventu" + 0.043*"bad" + 0.022*"carthag" + 0.021*"knox" + 0.020*"tri" + 0.019*"second" + 0.018*"leav" + 0.017*"propaganda"')
#
#
# Topic: 187
# Words: (187, '0.208*"silent" + 0.160*"quantum" + 0.125*"strang" + 0.079*"primit" + 0.052*"dawson" + 0.046*"flesh" + 0.042*"sunris" + 0.033*"conway" + 0.027*"cinematographi" + 0.023*"valentino"')
#
#
# Topic: 188
# Words: (188, '0.111*"hat" + 0.094*"motorway" + 0.088*"thrash" + 0.081*"slayer" + 0.061*"kerri" + 0.058*"queue" + 0.050*"diplomaci" + 0.049*"racist" + 0.042*"confront" + 0.041*"negro"')
#
#
# Topic: 189
# Words: (189, '0.536*"energi" + 0.079*"potenti" + 0.033*"chang" + 0.032*"stirl" + 0.025*"kinet" + 0.018*"creat" + 0.017*"form" + 0.014*"need" + 0.013*"work" + 0.011*"joul"')
#
#
# Topic: 190
# Words: (190, '0.195*"yorkshir" + 0.183*"rid" + 0.096*"strategi" + 0.073*"tactic" + 0.046*"england" + 0.041*"displac" + 0.034*"dhaka" + 0.032*"bounti" + 0.028*"mutini" + 0.025*"pascal"')
#
#
# Topic: 191
# Words: (191, '0.696*"south" + 0.116*"korea" + 0.068*"korean" + 0.021*"seoul" + 0.021*"nigeria" + 0.018*"know" + 0.006*"nation" + 0.004*"lago" + 0.004*"main" + 0.004*"peopl"')
#
#
# Topic: 192
# Words: (192, '0.417*"journal" + 0.233*"push" + 0.056*"supervis" + 0.046*"meadow" + 0.031*"turnpik" + 0.022*"expressway" + 0.021*"merseysid" + 0.019*"parkway" + 0.019*"pull" + 0.013*"turn"')
#
#
# Topic: 193
# Words: (193, '0.597*"act" + 0.126*"dougla" + 0.071*"romania" + 0.042*"diana" + 0.028*"discontinu" + 0.022*"romanian" + 0.019*"instinct" + 0.014*"stub" + 0.012*"bucharest" + 0.010*"keller"')
#
#
# Topic: 194
# Words: (194, '0.637*"japan" + 0.292*"japanes" + 0.012*"know" + 0.008*"special" + 0.006*"releg" + 0.006*"trough" + 0.005*"stuttgart" + 0.004*"august" + 0.004*"wester" + 0.003*"penicillin"')
#
#
# Topic: 195
# Words: (195, '0.168*"bright" + 0.149*"tomato" + 0.108*"southeastern" + 0.105*"helen" + 0.090*"portion" + 0.058*"sindh" + 0.043*"nocturn" + 0.042*"seventeen" + 0.042*"amber" + 0.018*"appear"')
#
#
# Topic: 196
# Words: (196, '0.090*"salmon" + 0.079*"luxuri" + 0.076*"silk" + 0.068*"bed" + 0.065*"dinner" + 0.064*"accessori" + 0.055*"retail" + 0.042*"pact" + 0.036*"trout" + 0.034*"barnard"')
#
#
# Topic: 197
# Words: (197, '0.184*"sort" + 0.100*"possess" + 0.094*"evolutionari" + 0.079*"synthesi" + 0.030*"garbag" + 0.026*"dump" + 0.025*"weber" + 0.020*"jade" + 0.018*"purcel" + 0.018*"obo"')
#
#
# Topic: 198
# Words: (198, '0.320*"norway" + 0.079*"oslo" + 0.046*"warp" + 0.038*"glow" + 0.036*"bologna" + 0.031*"aladdin" + 0.026*"comun" + 0.024*"stud" + 0.024*"alsac" + 0.024*"loom"')
#
#
# Topic: 199
# Words: (199, '0.879*"group" + 0.014*"includ" + 0.010*"consist" + 0.010*"subgroup" + 0.006*"leav" + 0.006*"found" + 0.006*"base" + 0.005*"zoo" + 0.005*"fdfdfd" + 0.004*"keen"')
#
#
# Topic: 200
# Words: (200, '0.607*"littl" + 0.039*"eros" + 0.033*"tuscani" + 0.029*"peel" + 0.028*"shrimp" + 0.025*"tori" + 0.024*"mermaid" + 0.015*"harriet" + 0.011*"simplex" + 0.010*"lifelong"')
#
#
# Topic: 201
# Words: (201, '0.392*"hour" + 0.115*"intens" + 0.056*"landfal" + 0.055*"weaken" + 0.031*"scale" + 0.025*"persuad" + 0.022*"rhetor" + 0.021*"saffir" + 0.018*"odor" + 0.016*"congenit"')
#
#
# Topic: 202
# Words: (202, '0.398*"apart" + 0.109*"sudan" + 0.095*"rent" + 0.033*"lumin" + 0.032*"smuggl" + 0.030*"tenant" + 0.025*"small" + 0.024*"lace" + 0.019*"form" + 0.016*"landlord"')
#
#
# Topic: 203
# Words: (203, '0.272*"shoot" + 0.115*"screen" + 0.079*"plastic" + 0.065*"forward" + 0.065*"pull" + 0.053*"curv" + 0.045*"tie" + 0.037*"arrow" + 0.036*"loos" + 0.018*"archer"')
#
#
# Topic: 204
# Words: (204, '0.198*"reserv" + 0.189*"genera" + 0.119*"subfamili" + 0.104*"roosevelt" + 0.065*"theodor" + 0.033*"kuwait" + 0.032*"spur" + 0.025*"quentin" + 0.025*"archi" + 0.020*"largest"')
#
#
# Topic: 205
# Words: (205, '0.638*"design" + 0.077*"architect" + 0.043*"broad" + 0.041*"architectur" + 0.022*"mercia" + 0.020*"neal" + 0.016*"work" + 0.015*"overlap" + 0.014*"know" + 0.010*"best"')
#
#
# Topic: 206
# Words: (206, '0.488*"scienc" + 0.261*"fiction" + 0.036*"alien" + 0.020*"place" + 0.016*"world" + 0.011*"take" + 0.009*"adhes" + 0.009*"use" + 0.008*"call" + 0.008*"spaceship"')
#
#
# Topic: 207
# Words: (207, '0.162*"franchis" + 0.149*"fan" + 0.144*"wonder" + 0.104*"amateur" + 0.094*"trek" + 0.067*"pyramid" + 0.039*"alexandra" + 0.037*"paramount" + 0.018*"enterpris" + 0.017*"origin"')
#
#
# Topic: 208
# Words: (208, '0.391*"charg" + 0.112*"incom" + 0.084*"tone" + 0.057*"erot" + 0.053*"regim" + 0.026*"incred" + 0.023*"gorilla" + 0.018*"zoologist" + 0.014*"say" + 0.013*"call"')
#
#
# Topic: 209
# Words: (209, '0.522*"award" + 0.152*"academi" + 0.140*"best" + 0.045*"emmi" + 0.037*"year" + 0.023*"give" + 0.013*"includ" + 0.011*"american" + 0.009*"nation" + 0.009*"origin"')
#
#
# Topic: 210
# Words: (210, '0.105*"oath" + 0.100*"nicol" + 0.096*"swear" + 0.066*"suspend" + 0.062*"allison" + 0.057*"chew" + 0.048*"coma" + 0.034*"alkali" + 0.032*"kidman" + 0.031*"rockwel"')
#
#
# Topic: 211
# Words: (211, '0.286*"execut" + 0.273*"code" + 0.125*"instruct" + 0.068*"walker" + 0.068*"processor" + 0.035*"filipino" + 0.023*"collector" + 0.021*"unit" + 0.019*"koch" + 0.013*"byte"')
#
#
# Topic: 212
# Words: (212, '0.743*"forc" + 0.093*"exchang" + 0.014*"call" + 0.014*"arbor" + 0.011*"special" + 0.010*"strong" + 0.010*"confin" + 0.009*"form" + 0.008*"involv" + 0.006*"take"')
#
#
# Topic: 213
# Words: (213, '0.240*"singer" + 0.124*"blue" + 0.110*"american" + 0.078*"songwrit" + 0.076*"sing" + 0.054*"soul" + 0.044*"bear" + 0.035*"know" + 0.033*"solo" + 0.030*"music"')
#
#
# Topic: 214
# Words: (214, '0.615*"famili" + 0.150*"genus" + 0.032*"includ" + 0.029*"morgan" + 0.023*"know" + 0.014*"live" + 0.012*"name" + 0.011*"larg" + 0.010*"contain" + 0.007*"place"')
#
#
# Topic: 215
# Words: (215, '0.210*"birth" + 0.187*"address" + 0.163*"identifi" + 0.119*"blind" + 0.058*"assign" + 0.040*"give" + 0.031*"gateway" + 0.030*"realiz" + 0.023*"place" + 0.020*"puck"')
#
#
# Topic: 216
# Words: (216, '0.197*"shoe" + 0.136*"pianist" + 0.090*"sheffield" + 0.075*"vultur" + 0.062*"shire" + 0.036*"heel" + 0.034*"raini" + 0.031*"namco" + 0.018*"call" + 0.018*"mulligan"')
#
#
# Topic: 217
# Words: (217, '0.272*"kentucki" + 0.099*"richmond" + 0.048*"patch" + 0.044*"georgetown" + 0.044*"louisvill" + 0.043*"lexington" + 0.041*"state" + 0.039*"hansen" + 0.036*"unit" + 0.034*"american"')
#
#
# Topic: 218
# Words: (218, '0.240*"speech" + 0.192*"kelli" + 0.126*"grace" + 0.035*"satan" + 0.031*"say" + 0.028*"anton" + 0.028*"potteri" + 0.025*"give" + 0.023*"anita" + 0.022*"know"')
#
#
# Topic: 219
# Words: (219, '0.364*"stock" + 0.119*"boil" + 0.069*"strain" + 0.043*"teammat" + 0.027*"soak" + 0.026*"bolshevik" + 0.023*"sake" + 0.021*"broth" + 0.020*"tangl" + 0.017*"sauber"')
#
#
# Topic: 220
# Words: (220, '0.854*"wikt" + 0.010*"cheroke" + 0.009*"litr" + 0.009*"usual" + 0.008*"petrol" + 0.006*"instead" + 0.004*"quick" + 0.004*"bose" + 0.004*"need" + 0.004*"use"')
#
#
# Topic: 221
# Words: (221, '0.272*"earth" + 0.204*"effect" + 0.071*"global" + 0.051*"atmospher" + 0.045*"warm" + 0.024*"terrestri" + 0.022*"caus" + 0.020*"venus" + 0.019*"larg" + 0.017*"place"')
#
#
# Topic: 222
# Words: (222, '0.599*"direct" + 0.046*"diagram" + 0.046*"graph" + 0.038*"counter" + 0.037*"show" + 0.021*"indirect" + 0.020*"call" + 0.014*"relat" + 0.014*"cigarett" + 0.013*"handbal"')
#
#
# Topic: 223
# Words: (223, '0.222*"attach" + 0.118*"skull" + 0.081*"roof" + 0.064*"concret" + 0.045*"caviti" + 0.045*"reinforc" + 0.038*"vowel" + 0.026*"bathurst" + 0.025*"frontal" + 0.021*"like"')
#
#
# Topic: 224
# Words: (224, '0.243*"lower" + 0.196*"egypt" + 0.107*"egyptian" + 0.104*"crown" + 0.052*"ancient" + 0.033*"burial" + 0.033*"pharaoh" + 0.030*"moss" + 0.028*"advis" + 0.013*"upper"')
#
#
# Topic: 225
# Words: (225, '0.338*"andrew" + 0.164*"frederick" + 0.127*"montana" + 0.089*"caesar" + 0.053*"julius" + 0.028*"gaius" + 0.018*"kabul" + 0.018*"thistl" + 0.013*"springsteen" + 0.013*"neural"')
#
#
# Topic: 226
# Words: (226, '0.472*"home" + 0.157*"stadium" + 0.096*"string" + 0.076*"arena" + 0.059*"son" + 0.015*"call" + 0.014*"name" + 0.011*"chang" + 0.010*"place" + 0.007*"expo"')
#
#
# Topic: 227
# Words: (227, '0.380*"document" + 0.142*"caption" + 0.049*"thorn" + 0.048*"dian" + 0.047*"entitl" + 0.033*"behalf" + 0.032*"denis" + 0.024*"clam" + 0.020*"mussel" + 0.019*"misus"')
#
#
# Topic: 228
# Words: (228, '0.294*"spain" + 0.260*"generat" + 0.213*"spanish" + 0.034*"liter" + 0.034*"second" + 0.019*"produc" + 0.013*"imam" + 0.010*"systemat" + 0.009*"otter" + 0.009*"weasel"')
#
#
# Topic: 229
# Words: (229, '0.231*"hero" + 0.166*"steven" + 0.077*"tyler" + 0.068*"dale" + 0.058*"birthplac" + 0.040*"starr" + 0.038*"render" + 0.029*"saga" + 0.029*"sunset" + 0.028*"clayton"')
#
#
# Topic: 230
# Words: (230, '0.214*"tissu" + 0.201*"delet" + 0.168*"approxim" + 0.048*"cortex" + 0.032*"quick" + 0.025*"tenor" + 0.025*"filament" + 0.018*"saxophon" + 0.018*"bariton" + 0.017*"contain"')
#
#
# Topic: 231
# Words: (231, '0.358*"borough" + 0.220*"status" + 0.134*"detail" + 0.098*"pioneer" + 0.051*"unsuccess" + 0.025*"islington" + 0.013*"offici" + 0.010*"have" + 0.010*"radial" + 0.009*"helm"')
#
#
# Topic: 232
# Words: (232, '0.279*"devic" + 0.137*"appl" + 0.118*"connect" + 0.100*"switch" + 0.055*"nois" + 0.024*"need" + 0.021*"use" + 0.018*"allow" + 0.017*"exampl" + 0.015*"differ"')
#
#
# Topic: 233
# Words: (233, '0.325*"complic" + 0.126*"necessari" + 0.117*"map" + 0.080*"milan" + 0.062*"nowaday" + 0.020*"magistr" + 0.020*"braveri" + 0.019*"cartographi" + 0.015*"provenc" + 0.015*"show"')
#
#
# Topic: 234
# Words: (234, '0.203*"congo" + 0.108*"greg" + 0.105*"hammer" + 0.079*"vista" + 0.049*"glide" + 0.045*"democrat" + 0.039*"glider" + 0.037*"boyl" + 0.028*"acacia" + 0.022*"zimmer"')
#
#
# Topic: 235
# Words: (235, '0.266*"machin" + 0.174*"marin" + 0.083*"automat" + 0.082*"diego" + 0.051*"gun" + 0.048*"rifl" + 0.029*"courag" + 0.020*"firearm" + 0.013*"work" + 0.013*"ammunit"')
#
#
# Topic: 236
# Words: (236, '0.204*"recreat" + 0.158*"holm" + 0.066*"abbott" + 0.059*"doyl" + 0.046*"scarlet" + 0.043*"conan" + 0.040*"portag" + 0.037*"sherlock" + 0.037*"memor" + 0.031*"spare"')
#
#
# Topic: 237
# Words: (237, '0.484*"tree" + 0.150*"succeed" + 0.070*"fifti" + 0.041*"grow" + 0.035*"leav" + 0.018*"small" + 0.015*"abram" + 0.014*"department" + 0.014*"gorbachev" + 0.012*"unfair"')
#
#
# Topic: 238
# Words: (238, '0.352*"ocean" + 0.202*"pacif" + 0.166*"atlant" + 0.046*"slowli" + 0.029*"lancashir" + 0.017*"name" + 0.015*"world" + 0.015*"blackpool" + 0.014*"call" + 0.011*"stub"')
#
#
# Topic: 239
# Words: (239, '0.285*"commerci" + 0.101*"trail" + 0.060*"toe" + 0.053*"regga" + 0.042*"shade" + 0.035*"pleistocen" + 0.033*"wasn" + 0.030*"livingston" + 0.028*"huntington" + 0.027*"mick"')
#
#
# Topic: 240
# Words: (240, '0.444*"northern" + 0.281*"ireland" + 0.057*"dean" + 0.042*"puerto" + 0.033*"rico" + 0.013*"ulster" + 0.012*"gloucest" + 0.010*"bere" + 0.007*"tyron" + 0.007*"largest"')
#
#
# Topic: 241
# Words: (241, '0.203*"gregori" + 0.127*"sysop" + 0.121*"clara" + 0.069*"admin" + 0.055*"fife" + 0.040*"apocalyps" + 0.038*"peck" + 0.036*"heaviest" + 0.032*"hypertens" + 0.023*"curi"')
#
#
# Topic: 242
# Words: (242, '0.165*"safe" + 0.123*"sheet" + 0.096*"hook" + 0.084*"fusion" + 0.073*"harper" + 0.067*"camden" + 0.045*"fuse" + 0.035*"overcom" + 0.033*"helium" + 0.031*"wanna"')
#
#
# Topic: 243
# Words: (243, '0.779*"time" + 0.052*"save" + 0.036*"chang" + 0.012*"venic" + 0.011*"marvel" + 0.011*"year" + 0.008*"longer" + 0.007*"giovanni" + 0.007*"daylight" + 0.005*"mean"')
#
#
# Topic: 244
# ...
#
#
# Topic: 919
# Words: (919, '0.590*"hold" + 0.095*"defeat" + 0.034*"heavyweight" + 0.028*"main" + 0.027*"smackdown" + 0.023*"world" + 0.016*"august" + 0.015*"take" + 0.013*"undertak" + 0.013*"john"')
#
#
# Topic: 920
# Words: (920, '0.232*"diseas" + 0.126*"caus" + 0.107*"affect" + 0.048*"peopl" + 0.044*"risk" + 0.043*"symptom" + 0.032*"common" + 0.031*"worst" + 0.028*"alzheim" + 0.022*"cure"')
#
#
# Topic: 921
# Words: (921, '0.109*"cipher" + 0.090*"cryptographi" + 0.051*"break" + 0.048*"dixon" + 0.044*"arthropod" + 0.042*"secur" + 0.040*"augusta" + 0.038*"password" + 0.036*"cryptograph" + 0.035*"cryptanalysi"')
#
#
# Topic: 922
# Words: (922, '0.297*"profession" + 0.201*"wrestl" + 0.148*"match" + 0.069*"mike" + 0.056*"american" + 0.046*"know" + 0.026*"work" + 0.023*"best" + 0.021*"wrestlemania" + 0.021*"pipe"')
#
#
# Topic: 923
# Words: (923, '0.450*"michigan" + 0.103*"withdraw" + 0.081*"pitcher" + 0.040*"uniti" + 0.037*"state" + 0.034*"buyer" + 0.031*"transact" + 0.029*"american" + 0.023*"migrant" + 0.014*"stub"')
#
#
# Topic: 924
# Words: (924, '0.241*"cape" + 0.179*"nevada" + 0.135*"vega" + 0.028*"hieroglyph" + 0.021*"contra" + 0.021*"reno" + 0.017*"die" + 0.015*"moorland" + 0.013*"take" + 0.013*"opus"')
#
#
# Topic: 925
# Words: (925, '0.453*"right" + 0.232*"civil" + 0.078*"activist" + 0.059*"american" + 0.028*"peopl" + 0.016*"malcolm" + 0.013*"unit" + 0.012*"nation" + 0.011*"start" + 0.009*"give"')
#
#
# Topic: 926
# Words: (926, '0.534*"winter" + 0.175*"spot" + 0.047*"lugano" + 0.028*"umbrella" + 0.023*"blanket" + 0.020*"guerrilla" + 0.018*"mandi" + 0.017*"ticino" + 0.014*"solstic" + 0.013*"diatom"')
#
#
# Topic: 927
# Words: (927, '0.548*"california" + 0.166*"valley" + 0.071*"state" + 0.042*"unit" + 0.021*"delhi" + 0.017*"wilder" + 0.010*"high" + 0.009*"bison" + 0.008*"stub" + 0.007*"mirag"')
#
#
# Topic: 928
# Words: (928, '0.168*"height" + 0.159*"pressur" + 0.105*"pain" + 0.103*"teeth" + 0.065*"pack" + 0.059*"trap" + 0.033*"altitud" + 0.029*"high" + 0.023*"helmet" + 0.021*"differ"')
#
#
# Topic: 929
# Words: (929, '0.417*"simpl" + 0.238*"acid" + 0.085*"weak" + 0.039*"base" + 0.033*"strong" + 0.023*"hydroxid" + 0.015*"zulu" + 0.012*"swaziland" + 0.011*"know" + 0.011*"xhosa"')
#
#
# Topic: 930
# Words: (930, '0.548*"arab" + 0.118*"emir" + 0.049*"camel" + 0.042*"dubai" + 0.038*"unit" + 0.036*"world" + 0.018*"countri" + 0.018*"dhabi" + 0.014*"lovel" + 0.011*"pastel"')
#
#
# Topic: 931
# Words: (931, '0.265*"liquid" + 0.254*"solid" + 0.129*"enjoy" + 0.042*"acronym" + 0.031*"snack" + 0.024*"like" + 0.022*"call" + 0.021*"differ" + 0.020*"exampl" + 0.017*"hungri"')
#
#
# Topic: 932
# Words: (932, '0.286*"weather" + 0.075*"leon" + 0.072*"sierra" + 0.054*"corn" + 0.039*"sharon" + 0.035*"glue" + 0.025*"elbow" + 0.025*"amor" + 0.024*"lori" + 0.020*"happen"')
#
#
# Topic: 933
# Words: (933, '0.091*"forecast" + 0.078*"comfort" + 0.069*"meteorolog" + 0.067*"consumpt" + 0.061*"infecti" + 0.050*"tuberculosi" + 0.050*"oracl" + 0.042*"proclaim" + 0.035*"saunder" + 0.034*"apach"')
#
#
# Topic: 934
# Words: (934, '0.661*"union" + 0.090*"kashmir" + 0.047*"state" + 0.037*"jammu" + 0.020*"azad" + 0.020*"gilgit" + 0.015*"baltistan" + 0.012*"stub" + 0.012*"last" + 0.010*"hist"')
#
#
# Topic: 935
# Words: (935, '0.263*"kent" + 0.139*"servant" + 0.069*"canterburi" + 0.039*"naughti" + 0.036*"england" + 0.027*"prank" + 0.027*"lar" + 0.026*"budapest" + 0.025*"spinoff" + 0.024*"gabor"')
#
#
# Topic: 936
# Words: (936, '0.443*"race" + 0.133*"formula" + 0.098*"driver" + 0.089*"scale" + 0.039*"prix" + 0.033*"team" + 0.025*"grand" + 0.011*"motor" + 0.011*"year" + 0.011*"start"')
#
#
# Topic: 937
# Words: (937, '0.329*"jack" + 0.181*"teenag" + 0.089*"pirat" + 0.067*"milwauke" + 0.045*"offspr" + 0.029*"astro" + 0.029*"brewer" + 0.026*"year" + 0.016*"ballpark" + 0.016*"mash"')
#
#
# Topic: 938
# Words: (938, '0.375*"digit" + 0.139*"camera" + 0.074*"photo" + 0.065*"photographi" + 0.063*"photograph" + 0.028*"take" + 0.027*"sensor" + 0.022*"scent" + 0.018*"use" + 0.015*"annoy"')
#
#
# Topic: 939
# Words: (939, '0.349*"surround" + 0.243*"plain" + 0.096*"ottawa" + 0.041*"pill" + 0.031*"cocoa" + 0.018*"cover" + 0.018*"larg" + 0.014*"consist" + 0.012*"herakl" + 0.012*"pelham"')
#
#
# Topic: 940
# Words: (940, '0.296*"experi" + 0.290*"scientist" + 0.087*"laboratori" + 0.048*"marathon" + 0.040*"jess" + 0.036*"work" + 0.032*"wellington" + 0.029*"chorus" + 0.021*"hornet" + 0.016*"sonni"')
#
#
# Topic: 941
# Words: (941, '0.293*"forest" + 0.079*"margaret" + 0.074*"habitat" + 0.069*"tropic" + 0.058*"effici" + 0.050*"subtrop" + 0.049*"temper" + 0.047*"riot" + 0.032*"live" + 0.027*"moist"')
#
#
# Topic: 942
# Words: (942, '0.434*"control" + 0.342*"model" + 0.019*"lime" + 0.019*"ivan" + 0.018*"conspiraci" + 0.012*"help" + 0.011*"use" + 0.009*"turn" + 0.009*"larg" + 0.008*"move"')
#
#
# Topic: 943
# Words: (943, '0.245*"deliv" + 0.195*"postal" + 0.074*"deliveri" + 0.042*"calhoun" + 0.032*"madhya" + 0.030*"bhopal" + 0.030*"state" + 0.029*"parcel" + 0.028*"place" + 0.024*"post"')
#
#
# Topic: 944
# Words: (944, '0.341*"stay" + 0.204*"cabl" + 0.076*"dwarf" + 0.049*"feast" + 0.033*"stalin" + 0.031*"lenin" + 0.025*"stellar" + 0.024*"perch" + 0.018*"zeta" + 0.017*"magellan"')
#
#
# Topic: 945
# Words: (945, '0.297*"martin" + 0.177*"protest" + 0.138*"reform" + 0.063*"corrupt" + 0.037*"luther" + 0.034*"salamand" + 0.032*"retain" + 0.024*"limb" + 0.022*"chang" + 0.019*"keyboardist"')
#
#
# Topic: 946
# Words: (946, '0.263*"kong" + 0.184*"hong" + 0.178*"fuel" + 0.056*"enterpris" + 0.047*"petroleum" + 0.039*"subsidiari" + 0.033*"mose" + 0.022*"coven" + 0.019*"exodus" + 0.019*"hydrocarbon"')
#
#
# Topic: 947
# Words: (947, '0.295*"rise" + 0.257*"surfac" + 0.221*"dark" + 0.057*"shadow" + 0.046*"obtain" + 0.020*"begin" + 0.017*"textur" + 0.011*"notion" + 0.008*"cover" + 0.006*"stub"')
#
#
# Topic: 948
# Words: (948, '0.305*"toni" + 0.200*"anthoni" + 0.099*"appar" + 0.077*"heir" + 0.059*"blair" + 0.026*"metaphor" + 0.022*"aeroplan" + 0.020*"throne" + 0.018*"kathryn" + 0.018*"stark"')
#
#
# Topic: 949
# Words: (949, '0.269*"distanc" + 0.148*"conduct" + 0.139*"basin" + 0.046*"discharg" + 0.037*"insul" + 0.036*"gas" + 0.033*"drainag" + 0.027*"drain" + 0.021*"short" + 0.019*"hoffman"')
#
#
# Topic: 950
# Words: (950, '0.274*"button" + 0.267*"david" + 0.204*"thoma" + 0.115*"marriag" + 0.110*"theme" + 0.010*"pant" + 0.005*"titus" + 0.003*"chang" + 0.002*"stub" + 0.002*"leav"')
#
#
# Topic: 951
# Words: (951, '0.199*"haut" + 0.126*"airbus" + 0.093*"seizur" + 0.059*"lanarkshir" + 0.055*"mcdonnel" + 0.053*"sim" + 0.037*"epilepsi" + 0.031*"binocular" + 0.031*"restart" + 0.022*"coutur"')
#
#
# Topic: 952
# Words: (952, '0.199*"camp" + 0.154*"armenia" + 0.142*"armenian" + 0.047*"refuge" + 0.038*"flee" + 0.034*"somalia" + 0.028*"peopl" + 0.026*"countri" + 0.022*"somali" + 0.020*"noah"')
#
#
# Topic: 953
# Words: (953, '0.281*"nelson" + 0.062*"salisburi" + 0.062*"packer" + 0.059*"char" + 0.054*"unemploy" + 0.049*"pedestrian" + 0.036*"redskin" + 0.033*"lombardi" + 0.032*"horatio" + 0.025*"trafalgar"')
#
#
# Topic: 954
# Words: (954, '0.164*"speed" + 0.136*"law" + 0.078*"principl" + 0.060*"coordin" + 0.059*"rotat" + 0.056*"faster" + 0.053*"constant" + 0.041*"newton" + 0.033*"isaac" + 0.027*"move"')
#
#
# Topic: 955
# Words: (955, '0.602*"good" + 0.098*"propos" + 0.058*"cluster" + 0.027*"think" + 0.024*"stub" + 0.020*"aggress" + 0.019*"hometown" + 0.015*"donna" + 0.011*"eton" + 0.010*"moos"')
#
#
# Topic: 956
# Words: (956, '0.475*"ontario" + 0.200*"toronto" + 0.111*"canada" + 0.085*"orlean" + 0.027*"morpholog" + 0.015*"pop" + 0.010*"landform" + 0.008*"join" + 0.008*"march" + 0.006*"nation"')
#
#
# Topic: 957
# Words: (957, '0.313*"actress" + 0.286*"american" + 0.076*"movi" + 0.071*"batman" + 0.070*"televis" + 0.023*"lynn" + 0.022*"know" + 0.017*"play" + 0.015*"best" + 0.011*"mate"')
#
#
# Topic: 958
# Words: (958, '0.277*"sister" + 0.236*"spend" + 0.073*"budget" + 0.072*"balanc" + 0.071*"year" + 0.045*"grove" + 0.038*"revenu" + 0.032*"aquarium" + 0.032*"captiv" + 0.020*"live"')
#
#
# Topic: 959
# Words: (959, '0.161*"trust" + 0.124*"warrior" + 0.107*"worship" + 0.093*"heaven" + 0.083*"theolog" + 0.064*"divin" + 0.053*"gloria" + 0.044*"catholic" + 0.026*"fide" + 0.026*"coptic"')
#
#
# Topic: 960
# Words: (960, '0.270*"legal" + 0.161*"lawyer" + 0.043*"advic" + 0.034*"counsel" + 0.032*"countri" + 0.027*"work" + 0.026*"laureat" + 0.024*"afternoon" + 0.022*"help" + 0.019*"laurel"')
#
#
# Topic: 961
# Words: (961, '0.660*"june" + 0.066*"statu" + 0.056*"die" + 0.041*"bear" + 0.021*"later" + 0.016*"septemb" + 0.013*"chamberlain" + 0.013*"second" + 0.010*"cornelius" + 0.009*"veronica"')
#
#
# Topic: 962
# Words: (962, '0.447*"imag" + 0.096*"step" + 0.093*"notic" + 0.080*"warn" + 0.076*"silver" + 0.027*"saxoni" + 0.025*"upload" + 0.015*"adel" + 0.014*"privileg" + 0.012*"cosmic"')
#
#
# Topic: 963
# Words: (963, '0.550*"announc" + 0.153*"golf" + 0.037*"ceram" + 0.027*"golfer" + 0.024*"barker" + 0.014*"blink" + 0.012*"say" + 0.011*"frill" + 0.010*"cover" + 0.009*"wharf"')
#
#
# Topic: 964
# Words: (964, '0.310*"length" + 0.124*"topic" + 0.072*"essay" + 0.067*"accur" + 0.050*"lesser" + 0.040*"short" + 0.037*"long" + 0.034*"longer" + 0.030*"karen" + 0.023*"higgin"')
#
#
# Topic: 965
# Words: (965, '0.229*"span" + 0.186*"inhabit" + 0.075*"rhine" + 0.044*"myanmar" + 0.041*"crete" + 0.039*"dogg" + 0.037*"westphalia" + 0.037*"ucla" + 0.034*"snoop" + 0.027*"burma"')
#
#
# Topic: 966
# Words: (966, '0.154*"beatl" + 0.099*"pepper" + 0.076*"lennon" + 0.075*"chronolog" + 0.067*"mccartney" + 0.034*"john" + 0.031*"inspector" + 0.031*"kite" + 0.027*"write" + 0.026*"granada"')
#
#
# Topic: 967
# Words: (967, '0.516*"head" + 0.207*"coach" + 0.105*"assist" + 0.034*"cowboy" + 0.024*"abort" + 0.016*"induc" + 0.014*"year" + 0.011*"bear" + 0.008*"nation" + 0.008*"fetus"')
#
#
# Topic: 968
# Words: (968, '0.267*"condit" + 0.153*"suffer" + 0.111*"injuri" + 0.056*"caus" + 0.051*"revers" + 0.041*"acquir" + 0.039*"result" + 0.028*"wors" + 0.021*"dementia" + 0.021*"form"')
#
#
# Topic: 969
# Words: (969, '0.406*"electr" + 0.297*"electron" + 0.023*"produc" + 0.020*"use" + 0.018*"usual" + 0.018*"high" + 0.018*"flow" + 0.016*"make" + 0.015*"call" + 0.014*"semiconductor"')
#
#
# Topic: 970
# Words: (970, '0.297*"mean" + 0.161*"disambig" + 0.127*"refer" + 0.119*"abbrevi" + 0.049*"licenc" + 0.045*"thing" + 0.035*"common" + 0.014*"turbo" + 0.013*"proprietari" + 0.012*"marley"')
#
#
# Topic: 971
# Words: (971, '0.228*"score" + 0.225*"goal" + 0.117*"quebec" + 0.076*"alex" + 0.062*"shorten" + 0.050*"creativ" + 0.025*"everybodi" + 0.018*"southampton" + 0.017*"shot" + 0.012*"anybodi"')
#
#
# Topic: 972
# Words: (972, '0.118*"pupil" + 0.098*"iri" + 0.080*"poker" + 0.080*"cheshir" + 0.046*"doncast" + 0.034*"leto" + 0.030*"flush" + 0.024*"costliest" + 0.024*"domingo" + 0.023*"ashoka"')
#
#
# Topic: 973
# Words: (973, '0.329*"coast" + 0.196*"zealand" + 0.107*"geolog" + 0.059*"coastal" + 0.041*"harbor" + 0.036*"cliff" + 0.034*"payment" + 0.030*"greenland" + 0.030*"glacier" + 0.026*"vike"')
#
#
# Topic: 974
# Words: (974, '0.457*"notabl" + 0.117*"wish" + 0.113*"dictionari" + 0.073*"encyclopedia" + 0.034*"randolph" + 0.018*"hayley" + 0.015*"hearst" + 0.013*"name" + 0.010*"wilfr" + 0.010*"encycloped"')
#
#
# Topic: 975
# Words: (975, '0.210*"wrong" + 0.153*"moral" + 0.092*"tribun" + 0.082*"algeria" + 0.077*"jacksonvill" + 0.062*"peopl" + 0.038*"say" + 0.031*"benson" + 0.024*"berber" + 0.023*"duval"')
#
#
# Topic: 976
# Words: (976, '0.321*"launch" + 0.199*"welsh" + 0.130*"spacecraft" + 0.074*"appropri" + 0.042*"propel" + 0.038*"boycott" + 0.025*"peopl" + 0.022*"wale" + 0.021*"nonviol" + 0.018*"propuls"')
#
#
# Topic: 977
# Words: (977, '0.236*"car" + 0.169*"motor" + 0.118*"automobil" + 0.039*"ricki" + 0.036*"produc" + 0.033*"jaguar" + 0.031*"butt" + 0.023*"saloon" + 0.021*"logist" + 0.018*"automot"')
#
#
# Topic: 978
# Words: (978, '0.520*"offic" + 0.200*"polic" + 0.064*"challeng" + 0.032*"mistak" + 0.025*"grade" + 0.016*"spongebob" + 0.013*"squarep" + 0.011*"march" + 0.011*"northampton" + 0.009*"work"')
#
#
# Topic: 979
# Words: (979, '0.177*"browser" + 0.105*"html" + 0.077*"gibson" + 0.052*"webpag" + 0.044*"unclear" + 0.043*"hutton" + 0.039*"markup" + 0.033*"gerard" + 0.031*"javascript" + 0.030*"mack"')
#
#
# Topic: 980
# Words: (980, '0.373*"mind" + 0.096*"innoc" + 0.044*"think" + 0.028*"delic" + 0.026*"stein" + 0.023*"kipl" + 0.019*"later" + 0.019*"come" + 0.018*"want" + 0.017*"dreyfus"')
#
#
# Topic: 981
# Words: (981, '0.560*"manag" + 0.072*"tampa" + 0.058*"eurovis" + 0.046*"tongu" + 0.043*"subord" + 0.035*"ant" + 0.033*"claw" + 0.026*"jacket" + 0.015*"aargau" + 0.014*"buccan"')
#
#
# Topic: 982
# Words: (982, '0.258*"characterist" + 0.147*"trait" + 0.130*"eugen" + 0.072*"ralli" + 0.036*"nitro" + 0.033*"emerald" + 0.031*"undercov" + 0.029*"camill" + 0.027*"need" + 0.022*"inferior"')
#
#
# Topic: 983
# Words: (983, '0.130*"abolish" + 0.104*"collin" + 0.093*"gabriel" + 0.079*"nicola" + 0.073*"uruguay" + 0.067*"casino" + 0.066*"gambl" + 0.066*"marc" + 0.059*"outcom" + 0.047*"cage"')
#
#
# Topic: 984
# Words: (984, '0.417*"india" + 0.236*"indian" + 0.071*"khan" + 0.067*"estim" + 0.033*"state" + 0.030*"nation" + 0.016*"partit" + 0.015*"subcontin" + 0.012*"muhammad" + 0.012*"year"')
#
#
# Topic: 985
# Words: (985, '0.378*"go" + 0.156*"run" + 0.090*"interst" + 0.063*"highway" + 0.047*"long" + 0.038*"near" + 0.026*"state" + 0.023*"theatric" + 0.022*"illus" + 0.017*"aromat"')
#
#
# Topic: 986
# Words: (986, '0.246*"hampshir" + 0.056*"portsmouth" + 0.047*"concord" + 0.047*"emerson" + 0.042*"kenni" + 0.038*"orchid" + 0.036*"speedway" + 0.036*"puritan" + 0.035*"sophia" + 0.032*"american"')
#
#
# Topic: 987
# Words: (987, '0.277*"probabl" + 0.143*"error" + 0.092*"shakespear" + 0.068*"spiritu" + 0.065*"seek" + 0.056*"cuba" + 0.055*"dominican" + 0.043*"experiment" + 0.039*"hypothesi" + 0.036*"carv"')
#
#
# Topic: 988
# Words: (988, '0.436*"band" + 0.108*"rock" + 0.046*"punk" + 0.041*"form" + 0.041*"music" + 0.037*"american" + 0.035*"member" + 0.025*"state" + 0.024*"unit" + 0.023*"start"')
#
#
# Topic: 989
# Words: (989, '0.700*"sign" + 0.044*"cap" + 0.034*"boon" + 0.017*"show" + 0.016*"give" + 0.014*"wiener" + 0.012*"leav" + 0.012*"spywar" + 0.009*"loaf" + 0.009*"refer"')
#
#
# Topic: 990
# Words: (990, '0.184*"monkey" + 0.083*"rainforest" + 0.083*"retreat" + 0.080*"primat" + 0.067*"live" + 0.058*"world" + 0.042*"snowi" + 0.037*"pygmi" + 0.023*"bland" + 0.020*"marmoset"')
#
#
# Topic: 991
# Words: (991, '0.237*"canal" + 0.189*"hart" + 0.118*"geoffrey" + 0.087*"conrad" + 0.042*"waterway" + 0.036*"cranston" + 0.023*"connect" + 0.022*"cholera" + 0.017*"foremost" + 0.017*"barg"')
#
#
# Topic: 992
# Words: (992, '0.243*"previous" + 0.184*"opposit" + 0.112*"till" + 0.094*"ukrain" + 0.073*"oppos" + 0.059*"gather" + 0.055*"ukrainian" + 0.052*"victor" + 0.048*"argu" + 0.012*"viktor"')
#
#
# Topic: 993
# Words: (993, '0.166*"utah" + 0.147*"devil" + 0.133*"spirit" + 0.088*"imposs" + 0.082*"hell" + 0.052*"demon" + 0.026*"obey" + 0.026*"pitchfork" + 0.021*"serpent" + 0.019*"like"')
#
#
# Topic: 994
# Words: (994, '0.636*"field" + 0.143*"magnet" + 0.025*"development" + 0.017*"agn" + 0.017*"flux" + 0.011*"spill" + 0.010*"notifi" + 0.007*"electromagnet" + 0.007*"tesla" + 0.006*"marcellus"')
#
#
# Topic: 995
# Words: (995, '0.345*"thousand" + 0.095*"year" + 0.075*"alga" + 0.051*"mutual" + 0.050*"franco" + 0.037*"inact" + 0.036*"slovenia" + 0.023*"liga" + 0.020*"dormant" + 0.014*"reorgan"')
#
#
# Topic: 996
# Words: (996, '0.414*"bird" + 0.072*"migrat" + 0.050*"bat" + 0.042*"nest" + 0.041*"widespread" + 0.026*"live" + 0.025*"small" + 0.022*"larg" + 0.021*"know" + 0.019*"common"')
#
#
# Topic: 997
# Words: (997, '0.300*"captain" + 0.269*"find" + 0.139*"hundr" + 0.050*"jake" + 0.031*"clerk" + 0.029*"surgic" + 0.022*"year" + 0.020*"place" + 0.014*"take" + 0.013*"disclaim"')
#
#
# Topic: 998
# Words: (998, '0.544*"seven" + 0.133*"hindu" + 0.033*"scriptur" + 0.030*"hindus" + 0.030*"morton" + 0.028*"uttar" + 0.014*"chiral" + 0.013*"anemon" + 0.011*"name" + 0.010*"juneau"')
#
#
# Topic: 999
# Words: (999, '0.566*"town" + 0.078*"peopl" + 0.051*"live" + 0.039*"small" + 0.027*"place" + 0.027*"england" + 0.023*"near" + 0.022*"charter" + 0.020*"main" + 0.016*"stub"')

# %%
def test(test): 
  bow_vector = dictionary.doc2bow(preprocess(test))

  for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))


test("Unity 3d")
# Out:
# Score: 0.5005000233650208	 Topic: 0.450*"michigan" + 0.103*"withdraw" + 0.081*"pitcher" + 0.040*"uniti" + 0.037*"state"

# %%
# return stemmed version of word with topic spell checked
! pip install autocorrect
from autocorrect import Speller 
spell = Speller()

def test(test): 
  bow_vector = dictionary.doc2bow(preprocess(test))

  for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, spell(lda_model.print_topic(index, 5))))


test("Soccer")
# Out:
# Requirement already satisfied: autocorrect in /usr/local/lib/python3.6/dist-packages (0.4.4)
# Score: 0.5005000233650208	 Topic: 0.387*"football" + 0.316*"assoc" + 0.063*"american" + 0.057*"unit" + 0.050*"soccer"
